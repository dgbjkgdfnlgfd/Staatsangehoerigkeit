# %%
import pandas as pd

# csv-datei laden
df = pd.read_csv(r"C:\Users\Momo\Desktop\speeches.csv")

# werte der datum spalte ausgeben
unique_dates = df['date'].unique()
print(unique_dates)
# Out:
# ['1949-09-12' '1949-09-15' '1949-09-20' ... '2021-05-05' '2021-05-06'
#  '2021-05-07']

# %%
# dataframe anzeigen lassen um spaltennamen angezeigt zu bekommen
df
# Out:
#              id  session  electoralTerm firstName    lastName  politicianId  \
# 0             0        2              1       NaN      Köhler      11001150
# 1             1        2              1       NaN      Arnold            -1
# 2             2        2              1       NaN      Köhler      11001150
# 3             3        2              1       NaN       Heuss            -1
# 4             4        2              1       NaN      Köhler      11001150
# ...         ...      ...            ...       ...         ...           ...
# 907639  1060953      228             19     Helge       Lindh      11004802
# 907640  1060954      228             19     Petra         Pau      11003206
# 907641  1060955      228             19     Helge       Lindh      11004802
# 907642  1060956      228             19     Petra         Pau      11003206
# 907643  1060957      228             19   Tankred  Schipanski      11004143
#
# ...

# %%
#datum
wanted_date = ('2019-05-16')

# Spalten mit gewünschtem Datum filtern
filtered_df = df[df['date'] == wanted_date][['speechContent', 'date', 'id', 'lastName']]
print(filtered_df)

#in csv-datei schreiben
filtered_df.to_csv('s2014063.csv', index=False)
# Out:
#                                             speechContent        date  \
# 869977  \n\nSehr geehrter Herr Präsident! Liebe Kolleg...  2019-05-16
# 870135  \n\nSehr geehrter Herr Präsident! Sehr geehrte...  2019-05-16
# 870149  \n\nHerr Präsident! Sehr geehrte Damen und Her...  2019-05-16
# 870358  \n\nHerr Präsident! Liebe Kolleginnen und Koll...  2019-05-16
# 871330  \n\nFrau Präsidentin! Liebe Kolleginnen und Ko...  2019-05-16
# ...                                                   ...         ...
# 872113  \n\nFür die Fraktion der SPD hat das Wort der ...  2019-05-16
# 872114  \n\nHerr Präsident! Sehr verehrte Damen und He...  2019-05-16
# 872115  \n\nDer nächste Redner ist für die FDP-Fraktio...  2019-05-16
# 872116  \n\nVielen Dank. – Herr Präsident! Liebe Kolle...  2019-05-16
# 872117  \n\nHerr Präsident! Liebe Kolleginnen und Koll...  2019-05-16
#
#              id   lastName
# 869977  1025058   Dobrindt
# 870135  1025230   Frömming
# 870149  1025247     Suding
# ...
