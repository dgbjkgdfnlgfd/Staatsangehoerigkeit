# %%
# file reading and writing
import os

# %%
# xml parser
import xml.etree.ElementTree as ET

# %%
# regex
import re

# %%
# to save dictionary to JSON file
import json

# %%
path_to_folder = "C:\\Users\\emily_x4gfebk\\Desktop\\NLP\\Staatsangehoerigkeit\\Data19PlenarDocs\\DrittesGesetz"
path_to_files = sorted ([os.path.join(path_to_folder, f) for f in os.listdir(path_to_folder)])
print (path_to_files)
# Out:
# ['C:\\Users\\emily_x4gfebk\\Desktop\\NLP\\Staatsangehoerigkeit\\Data19PlenarDocs\\DrittesGesetz\\19101.xml', 'C:\\Users\\emily_x4gfebk\\Desktop\\NLP\\Staatsangehoerigkeit\\Data19PlenarDocs\\DrittesGesetz\\19107.xml']

# %%
plenarliste = []
for my_file in path_to_files:
    with open(my_file, 'r', encoding = 'utf-8') as f:
        plenarliste.append(f.read())
print(plenarliste[0])
# Out:
# <?xml version="1.0" encoding="UTF-8"?>
# <DOKUMENT>
#   <WAHLPERIODE>19</WAHLPERIODE>
#   <DOKUMENTART>PLENARPROTOKOLL</DOKUMENTART>
#   <NR>19/101</NR>
#   <DATUM>16.05.2019</DATUM>
#   <TITEL>Plenarprotokoll vom 16.05.2019</TITEL>
#   <TEXT>Plenarprotokoll 19/101
# Deutscher Bundestag
# Stenografischer Bericht
# 101. Sitzung
# Berlin, Donnerstag, den 16. Mai 2019
# Inhalt:
# Glückwünsche zum Geburtstag des Abgeord-
# neten Johannes Röring   .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  12141 A
# Erweiterung und Abwicklung der Tagesord-
# nung .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  12141 A
# Absetzung der Tagesordnungspunkte 16, 18,
# 22, 24 d und 30 c  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  12143 B
# Nachträgliche Ausschussüberweisung   .  .  .  .  .  .  12143 C
# Tagesordnungspunkt 4:
# Vereinbarte Debatte: 70 Jahre Grundgesetz
# ...

# %%
tree = ET.ElementTree(ET.fromstring(plenarliste[0]))

# %%
root = tree.getroot()

# %%
rededict = {}
print("Inhalt aller Reden im Dokument:")
# Out:
# Inhalt aller Reden im Dokument:

# %%
# Leerzeichen und "\xa0" rausnehmen
# Zieht den Inhalt raus, den wir haben wollen (vom Redetext)
#for rede in root.iter('rede'):
#    redefraktion = rede.find("p/redner/name/fraktion").text.replace("\xa0", " ")

# %%
# in JSON Datei speichern
out_file = open("C:\\Users\\emily_x4gfebk\\Desktop\\NLP\\Staatsangehoerigkeit\\Data19PlenarDocs\\DrittesGesetz\\drittesGesetzText.json", "w", encoding = 'utf-8')
json.dump(plenarliste, out_file, indent = 5)
out_file.close()
