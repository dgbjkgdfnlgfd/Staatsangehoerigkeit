# %%
import pandas as pd
import numpy as np
import os

import gensim
import gensim.corpora as corpora
from gensim.models import CoherenceModel
import spacy
nlp = spacy.load("de_core_news_sm")

# %%
# run 'pip install pyLDAvis' first (Python library for interactive topic model visualization)
import pyLDAvis 
import pyLDAvis.gensim_models

# %%
# load speech data:
opendiscourse = pd.read_csv('speeches.csv')

# %%
extra_stop = ["herr", "dame", "präsident", "präsidentin", "bundespräsident", "bundespräsidentin", "frau", "damen", "herren", "kollege", "kollegin", "genau", "danke", "lieb", "tagesordnungspunkt", "bitte", "nächster", "nächste", "redner", "rednerin", "deutsch", "deutschland", "staatsangehörigkeit", "staatsbürgerschaft", "gesetzentwurf", "staatsangehörigkeitsrecht", "staatsangehörigkeitsgesetz"]
tokenized_corpus = [] # final tokenized corpus will be saved here

def tokenize(a,b):
    # go through the entries for our timeframes
    for i in range(a,b): 
    
        # iterate through the 'speechContent' column in row i 
        # replace new-line commands with white space
        # remove parentheses, brackets, hyphens
        speech = opendiscourse['speechContent'].iloc[i].replace('\n', ' ').replace('\xa0',' ').replace('({','').replace('})','').replace('-','').replace('--','')       
 
        # feed words to spaCy German language model
        tokenized_speech = nlp(speech) 
    
        # remove stop words, punctuation, numbers; lemmatize words
        speech_corpus = []
        for t in tokenized_speech:
            if not t.is_stop and not t.is_punct and not t.like_num and t.lemma_.lower() not in extra_stop:
                speech_corpus.append(t.lemma_.lower())
        while ' ' in speech_corpus:
            speech_corpus.remove(' ')
        while '  ' in speech_corpus:
            speech_corpus.remove('  ')
        while '   ' in speech_corpus:
            speech_corpus.remove('   ')
            
        tokenized_corpus.append(speech_corpus)

# %% [markdown]
# The topic modeling process will be performed for each year separately. Since the same list (tokenized_corpus) is used each time, the following code block (tokenized_corpus.clear()) must be executed before the beginning of each new topic modeling process in order to clear the results from the previous process. We'll print the list after it's been cleared in order to be sure that it's empty.

# %%
# clears the list of all entries (used before tokenizing a new session)
tokenized_corpus.clear()
print(tokenized_corpus)

# %%
# 2nd law change/2. Gesetzesänderung
# section relevant for discussion of citizenship law changes
# 2014-06-05 / 18039
tokenize(802050,802084)
# 2014-07-03 / 18046
tokenize(803506,803532)
print(tokenized_corpus)
# Out:
# [['schließen', 'aussprache', 'präsidium', 'kolbe', 'schätzung', 'teilen', 'thema', 'sicher', 'län', 'g', 'beratungszeit', 'verdienen', 'ausdruck', 'nachweislich', 'deutlich', 'län', 'ger', 'debattieren', 'beginn', 'debatte', 'gemeinsam', 'beschließen', 'interfraktionell', 'überweisung', 'gesetzent', 'wurfs', 'drucksache', 'tag', 'ordnung', 'aufgeführt', 'ausschuß', 'vorschlagen', 'alternativ', 'vorschlag', 'fall', 'überweisung', 'beschließen', '--', 'beratung', 'bundesregierung', 'eingebracht', 'entwurf', 'gesetz', 'änderung', 'drucksach', 'überweisungsvorschlag', 'innenausschuss', 'auswärtiger', 'ausschuss', 'ausschuss', 'verbraucherschutz', '--', 'beratung', 'abgeordneter', 'jan', 'korte', 'sevim', 'dağdele', 'dr.', 'andré', 'hahn', 'abgeordneter', 'fraktion', 'linke', 'eingebracht', 'entwurf', 'gesetz', 'aufhebung', 'optionsregelung', 'drucksache', 'überweisungsvorschlag', 'innenausschuss', 'ausschuss', 'verbraucherschutz', 'ausschuss', 'familie', 'senior', 'jugend', 'ausschuss', 'menschenrecht', 'humanitär', 'hilfe', 'aussprache', 'interfraktionell', 'vereinbarung', 'minute', 'vorsehen', 'offenkundig', 'allgemein', 'auffassung', 'verfahren', 'eröffnen', 'aussprache', 'erteil', 'bundesregierung', 'wort', 'parlamentarisch', 'staatssekretär', 'günter', 'krings'], ['warten', 'verehrt', 'schuster', 'beginn', 'ausführung', 'versäumen', 'bundesinnenminister', 'entschuldigen', 'rede', 'einbringung', 'änderung', 'selber', 'halten', 'teilnahme', 'justizundinneresrat', 'europäisch', 'union', 'luxemburg', 'binden', 'verständnis', 'ergänzen', 'minister', 'rede', 'selber', 'halten', 'vertreten', 'land', 'gering', 'zuwanderung', 'staat', 'wahrscheinlichkeit', 'mensch', 'gesamt', 'leben', 'region', 'stadt', 'dorf', 'verbringen', 'gebären', 'generation', 'jedenfalls', 'opfer', 'krieg', 'vertreibung', 'leben', 'gesellschaft', 'mobiler', 'mensch', 'wechseln', 'lebensmittelpunkt', 'regional', 'national', 'grenze', 'hinweg', 'ausbildung', 'familie', 'gründen', 'wirtschaftlich', 'not', 'karriere', 'wohnen', 'million', 'mensch', 'migrationshintergrund', 'entsprechen', 'fast', 'fünftel', 'wohnbevölkerung', 'einher', 'frage', 'heimat', 'heimat', 'nostalgisch', 'bedeutungssinn', 'wort', 'heimat', 'romantisch', 'verklärung', 'eher', 'nüchtern', 'grund', 'juristisch', 'begriff', 'bezeichnung', 'aufenthaltsstatus', 'heimatrecht', 'besonderer', 'aufenthalt', 'armenpfleg', 'pflicht', 'gemeinde', 'gehören', 'modern', 'prägung', 'historisch', 'entwickeln', 'ansatz', 'ius', 'sanguinis', 'ius', 'soli', 'ziel', 'festlegen', 'gemeinde', 'bestimmt', 'staat', 'gehören', 'wobei', 'annehmen', 'verwurzeln', 'regel', 'dauerhaft', 'bezug', 'lebensmittelpunkt', 'individuell', 'mobilität', 'gering', 'laufen', 'abstammung', 'geburtsort', 'häufig', 'hinaus', 'seither', 'grenzüberschreitend', 'mobilität', 'verhältnis', 'verkompliziern', 'nostalgisch', 'seite', 'begriff', 'heimat', 'betreffen', 'einzeln', 'fragen', 'eigentlich', 'haus', 'einstmals', 'juristisch', 'bedeutung', 'betreffen', 'heimatrecht', 'besonderer', 'rechtsstellung', 'bestimmt', 'gemeinwesen', 'mitunter', 'heftig', 'diskussion', 'doppelt', 'spiegeln', 'wider', 'lebensgewohnheit', 'jahrzehnt', 'rasant', 'verändern', 'überall', 'tragen', 'bundesregierung', 'rechnung', 'optionspflicht', 'regelung', 'vorschlagen', 'koalitionsvereinbarung', 'cdu', 'csu', 'spd', 'beschließen', 'auftrag', 'setzen', 'entwurf', 'finden', 'ausgleich', 'interesse', 'jung', 'deutsche', 'mehrfach', 'seite', 'seite', 'staatlich', 'interesse', 'beparl', 'staatssekretär', 'dr.', 'günter', 'kring', 'sond', 'loyalitäts', 'verantwortungsbeziehung', 'gemeinwesen', 'bürger', 'erhalten', 'einführung', 'sogenannter', 'iussoliregel', 'jahrzehnt', 'elternteil', 'mindestens', 'gewöhnlich', 'aufenthalt', 'erwerben', 'unser', 'land', 'geboren', 'kind', 'unabhängig', 'eltern', 'bisherig', 'rechtslage', 'kind', 'spätestens', 'vollendung', 'lebensjahr', 'eltern', 'entscheiden', 'jung', 'erwachsene', 'entscheidung', 'treffen', 'überwiegend', 'entscheid ...

# %%
# 3rd law change/3. Gesetzesänderung
# section relevant for discussion of citizenship law changes
# 2019-05-16 / 19101
tokenize(871973,871995)
# 2019-06-27 / 19107
tokenize(873697,873735)
print(tokenized_corpus)

# %%
# 4th law change/4. Gesetzesänderung
# section relevant for discussion of citizenship law changes
# 2021-04-22 / 19224
tokenize(906355,906360)
print(tokenized_corpus)

# %%
# building dictionary/mapping words to IDs
words_id = corpora.Dictionary(tokenized_corpus)

# creating corpus/corpus becomes a bag of words
corpus = [words_id.doc2bow(txt) for txt in tokenized_corpus]

# %%
# running the LDA model for our chosen number of topics (num_topics)
lda_model = gensim.models.ldamodel.LdaModel(corpus=corpus,
                                           id2word=words_id,
                                            # This number of topics may or may not be appropriate
                                           num_topics=3, 
                                           random_state=50, # seed for reproducibility
                                           passes=20, # the number of times the model is trained on our corpus
                                           per_word_topics=True)

# %%
# displays the first 20 words in each topic
# & the probability that those words belong to the topic
lda_model.show_topics(num_words=20,num_topics=3)
# Out:
# [(0,
#   '0.009*"mensch" + 0.007*"doppelt" + 0.005*"optionspflicht" + 0.005*"fall" + 0.005*"land" + 0.005*"besonderer" + 0.005*"sagen" + 0.004*"finden" + 0.004*"jung" + 0.004*"entscheiden" + 0.004*"unser" + 0.004*"eltern" + 0.003*"seite" + 0.003*"mehrstaatigkeit" + 0.003*"aufwachsen" + 0.003*"gehören" + 0.003*"entscheidung" + 0.003*"spd" + 0.003*"union" + 0.003*"gemeinwesen"'),
#  (1,
#   '0.010*"mensch" + 0.009*"sagen" + 0.009*"deutsche" + 0.007*"land" + 0.006*"gesetz" + 0.005*"kind" + 0.005*"fraktion" + 0.005*"optionspflicht" + 0.005*"linke" + 0.004*"gebären" + 0.004*"jung" + 0.004*"beck" + 0.004*"spd" + 0.004*"wort" + 0.004*"eltern" + 0.004*"beratung" + 0.004*"bundesregierung" + 0.004*"bündnis" + 0.004*"schritt" + 0.004*"wissen"'),
#  (2,
#   '0.009*"gesetz" + 0.009*"optionspflicht" + 0.008*"mensch" + 0.006*"land" + 0.006*"doppelt" + 0.005*"leben" + 0.004*"frage" + 0.004*"klar" + 0.004*"jung" + 0.004*"beck" + 0.003*"lassen" + 0.003*"bleiben" + 0.003*"wert" + 0.003*"unser" + 0.003*"europäisch" + 0.003*"behalten" + 0.003*"schule" + 0.003*"abschaffung" + 0.003*"sagen" + 0.003*"erfolgreich"')]

# %%
# Check for the optimal number of topics k using the c_v coherence score
# In order to use the visualization in the next cell, k_final in this cell 
# needs to be set to the number of topics desired for the visualization
k_init = 1
k_final = 3
for k in range(k_init,k_final+1):
    lda_model = gensim.models.ldamodel.LdaModel(corpus=corpus,
                                           id2word=words_id,
                                           num_topics=k, 
                                           random_state=50,
                                           passes=20,
                                           per_word_topics=True)
    # perplexity (lower score is better) 
    per_lda = lda_model.log_perplexity(corpus)
    
    # coherence score (higher score is better)
    coherence_model_lda = CoherenceModel(model=lda_model, texts=tokenized_corpus, dictionary=words_id, coherence='c_v')
    coherence_lda = coherence_model_lda.get_coherence()
    #print(coherence_lda)
    
    print('Anzahl der Topics:',k,'Perplexität:',per_lda,'Kohärenz:',coherence_lda)
# Out:
# Anzahl der Topics: 1 Perplexität: -7.5509288773027725 Kohärenz: 0.3187631648648244
# Anzahl der Topics: 2 Perplexität: -7.56097157345689 Kohärenz: 0.3834119191100726
# Anzahl der Topics: 3 Perplexität: -7.586579967889806 Kohärenz: 0.32836635586562907

# %%
# visualizing the topics
id2word=words_id
pyLDAvis.enable_notebook(local=True)
vis = pyLDAvis.gensim_models.prepare(lda_model, corpus, id2word)

pyLDAvis.display(vis)
# Out:
# <link rel="stylesheet" type="text/css" href="https://cdn.jsdelivr.net/gh/bmabey/pyLDAvis@3.4.0/pyLDAvis/js/ldavis.v1.0.0.css">
#
#
# <div id="ldavis_el1824823006235802721698095053" style="background-color:white;"></div>
# <script type="text/javascript">
#
# var ldavis_el1824823006235802721698095053_data = {"mdsDat": {"x": [-0.09730667621239174, 0.04215379308561072, 0.05515288312678106], "y": [0.006566174295120871, -0.07701123974122429, 0.07044506544610342], "topics": [1, 2, 3], "cluster": [1, 1, 1], "Freq": [43.84137166866473, 30.83306343834658, 25.325564892988687]}, "tinfo": {"Term": ["fraktion", "deutsche", "besonderer", "gemeinwesen", "drucksache", "doppelt", "beschlussempfehlung", "interesse", "geburt", "innenausschuss", "quote", "betroffener", "wert", "mehrstaatigkeit", "erfolgreich", "ausschuss", "staatsangeh\u00f6rigkeite", "bedeutung", "heimat", "entscheidung", "seite", "abstimmung", "klar", "b\u00fcndnis", "beratung", "fall", "erhalten", "geh\u00f6ren", "behalten", "tragen", "fraktion", "drucksache", "beschlussempfehlung", "innenausschuss", "quote", "ausschuss", "abstimmung", "eingebracht", "unternehmen", "aussprache", "platz", "--", "wirtschaft", "ablehnen", "empfehlen", "schlie\u00dfen", "besetzen", "ausl\u00e4nder", "drucksach", "sache", "sevim", "mann", "einzig", "hessen", "interfraktionell", "aufhebung", "box", "schriftf\u00fchrer", "    ", "ordnung", "deutsche", "b\u00fcndnis", "abgeordneter", "beratung", "da\u011fdele", "bundesregierung", "sagen", "entwurf", "linke", "volker", "gr\u00fcne", "enthalten", "mensch", "stimmen", "kind", "land", "geb\u00e4ren", "wissen", "schritt", "wort", "beck", "gesetz", "spd", "eltern", "jung", "cdu/csu", "sprechen", "optionspflicht", "prozent", "union", "aufwachsen", "\u00fcberzeugung", "wein", "v\u00f6llig", "vorliegend", "m\u00f6chten", "optionsverfahren", "auseinandersetzung", "gesellschaftlich", "t\u00fcrkisch", "zuwanderer", "migrantin", "mutlu", "zwischenfrage", "erfolgreich", "winzer", "seitens", "anh\u00f6ren", "sicherstellen", "vorstellung", "weltweit", "zunehmend", "rheinlandpfalz", "weinbau", "geografisch", "emotional", "vermeidung", "steigen", "k\u00fcnftig", "bundesratsinitiative", "pro", "wert", "gerne", "klar", "behalten", "person", "doppelpass", "lassen", "gesetz", "optionspflicht", "schule", "leben", "migrant", "festhalten", "gemeinsam", "abschlie\u00dfen", "mindestens", "doppelt", "sicherheit", "frage", "mensch", "land", "eigentlich", "bleiben", "beck", "abschaffung", "ziel", "unser", "jung", "europ\u00e4isch", "\u00e4nderung", "geben", "abschaffen", "wichtig", "tats\u00e4chlich", "sagen", "union", "gemeinwesen", "bedeutung", "heimat", "mehrstaatlichkeit", "aufbauen", "breit", "konsequenz", "beziehung", "definieren", "fast", "papier", "linie", "konflikt", "eu", "verwurzeln", "mehrfach", "geburt", "besonderer", "senden", "streit", "aufenthaltsrecht", "st\u00fcck", "berechtigen", "sozialdemokrat", "angewiesen", "wiederholen", "ge\u00e4ndert", "feld", "souver\u00e4n", "pr\u00e4gen", "interesse", "erhalten", "mehrstaatigkeit", "weg", "demokratisch", "konsens", "antwort", "tragen", "hinweisen", "hinnehmen", "innerhalb", "kommen", "entscheidung", "seite", "doppelt", "fall", "geh\u00f6ren", "betroffener", "halten", "finden", "entscheiden", "staatsangeh\u00f6rigkeite", "mensch", "unser", "optionspflicht", "eltern", "regelung", "land", "jung", "sagen", "aufwachsen", "einfach", "union", "spd", "bleiben", "europ\u00e4isch", "wort", "gesetz"], "Freq": [13.0, 29.0, 9.0, 6.0, 10.0, 32.0, 10.0, 7.0, 6.0, 9.0, 9.0, 8.0, 8.0, 8.0, 7.0, 8.0, 7.0, 4.0, 4.0, 9.0, 10.0, 7.0, 12.0, 12.0, 13.0, 18.0, 4.0, 10.0, 9.0, 5.0, 13.476958626668418, 10.36673849838074, 9.589336448953478, 8.811878648801049, 8.811591930785898, 8.033684806336575, 7.256351117917557, 6.4795523709805085, 6.4791919823642425, 6.479011456206555, 5.701152118093092, 4.924440979438451, 4.924077272326639, 4.92407660862753, 4.924043423672073, 4.9239495102481285, 4.9237958639043615, 4.923413241367939, 4.146732964721873, 4.146525226900711, 4.1465099618212005, 4.146459520688905, 4.146318152778657, 4.096091063446281, 3.3689592437934905, 3.3689512794041807, 3.3689383372715525, 3.36880393820195, 3.368761461458965, 3.368515892788581, 25.144976128599318, 10.409487358000817, 6.47993997 ...
