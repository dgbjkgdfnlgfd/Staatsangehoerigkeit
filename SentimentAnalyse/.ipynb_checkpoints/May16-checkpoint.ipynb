# %%
import pandas as pd

# %%
#mit dummytxt ausprobieren

# %%
import json

# %%
data = open(r'C:\Users\Momo\Desktop\Staatsangehoerigkeit\Data19PlenarDocs\DrittesGesetz\sitzung16Mai.json')
#mit tokenized text arbeiten

# %%
print(data)
# Out:
# <_io.TextIOWrapper name='C:\\Users\\Momo\\Desktop\\Staatsangehoerigkeit\\Data19PlenarDocs\\DrittesGesetz\\sitzung16Mai.json' mode='r' encoding='cp1252'>

# %%
plenar16 = json.load(data)

# %%
plenar16
# Out:
# [101,
#  19,
#  11003516,
#  '\n\nSehr geehrter Herr Präsident! Liebe Kolleginnen und Kollegen! Unser Grundgesetz ist ein Segen der deutschen Geschichte, mehr als die Summe seiner Artikel, mehr als ein historisches Dokument. Das Grundgesetz hat die Menschen in Deutschland für sich gewonnen.\n\n({0})\n\nMeine Damen und Herren, das Grundgesetz ist heute eine lebendige Verfassung für über 80\xa0Millionen Menschen in unserem Land, und es hat die Menschen im Laufe der Geschichte zweimal für sich gewonnen.\n\nUnser Grundgesetz ist entstanden nach nationalsozialistischer Diktatur, nach Krieg und Zerstörung. Deutschland war damals seiner geistigen Grundlage beraubt, moralisch gescheitert und entkernt. Und es waren einige wenige Entscheidungsträger im Parlamentarischen Rat, die in dieser Stunde mit dem Grundgesetz eine neue Werteordnung geschaffen haben und damit der Bundesrepublik einen ethisch-moralischen, wirtschaftlichen und gesellschaftlichen Neuanfang ermöglicht haben. Was damals einer kleinen Gruppe gelungen ist, wurde dann zu einer gemeinsamen, einer geteilten Überzeugung der Menschen in unserem Land. Aus einem Projekt der wenigen wurde eine Werteordnung für Millionen. Das ist ein Grund, warum wir heute feiern.\n\nAber das Grundgesetz hat auch ein zweites Mal die Menschen für sich gewonnen: vor 30\xa0Jahren, als die Menschen in der DDR bei den Montagsdemonstrationen auf die Straßen gingen. Denn diese Demonstrationen waren im Kern ja auch ein Ruf nach dem Grundgesetz, nach seinen Werten und seiner freiheitlich-demokratischen Grundordnung. In all den Jahren des Unrechts der DDR war es immer auch der dringende Appell der Präambel, „die Einheit und Freiheit Deutschlands zu vollenden“, die den Menschen im Osten Hoffnung gegeben hat, meine Damen und Herren.\n\n({1})\n\nWenn wir heute 70\xa0Jahre Grundgesetz feiern, dann feiern wir auch, dass Demokratie, Meinungsfreiheit und Menschenwürde stärker sind als Diktatur, als Stacheldraht, als Schießbefehl. Dieses Grundgesetz hat Mauern eingerissen und Menschen zusammengeführt. Heute ist unser Grundgesetz die gemeinsame Klammer, eine Klammer der Freiheit, der Gleichheit, der Brüderlichkeit, eine Klammer für Einigkeit, für Recht und Freiheit. Diese Klammer ist nicht nur so stark, weil sie uns als Bürger schützt, sondern vor allem, weil Bürger unsere Verfassung schützen. Das kann man zu Recht auch Patriotismus nennen.\n\n({2})\n\nMit dieser Klammer bildet das Grundgesetz übrigens auch die Voraussetzung für gelungene Integration. Wer integrieren will, der muss auch wissen, wohin\xa0– und wir wissen, wohin: in die Werteordnung unseres Grundgesetzes und seiner Grundsätze für das Zusammenleben in Deutschland.
schwerpunkt „digitale Bildung“ für die Lehrerausbildung gewählt. Da läuft etwas schief. Wer heute als Lehrer nicht mit digitalen Medien umgehen kann, der wird morgen nicht vor einer Klasse bestehen können. Das ist verantwortungslos. Da hätten Sie, Frau Ministerin Karliczek, viel früher nachsteuern müssen.\n\n({2})\n\n–\xa0Die ist nicht da.\n\nDrittens. Ties Rabe, SPD-Schulsenator in meiner Heimatstadt Hamburg, rühmt sich damit, dass er mit den Mitteln aus dem Digitalpakt 45\xa0000\xa0Computer für die Schulen anschaffen will. Gleichzeitig sagt er: Es sind nur zwei Lernprogramme vorhanden.\xa0– Für alle Unterrichtsfächer, Jahrgänge und Schulformen zusammen, wohlgemerkt. Nur zwei Lernprogramme! Das ist ein Witz. Das kann gar nicht funktionieren. Die Schulen brauchen eigene Budgets und mehr Freiheit, um digitale Schulbücher anzuschaffen. Die Politik muss hier runter von der Bremse.\n\n({3})\n\nViertens. Wir brauchen klare Standards für den Schutz sensibler Schüler- und Lerndaten. Will ein Lehrer eine Lernsoftware einsetzen, dann muss ein Schulleiter eine 120-seitige Datenschutzerklärung unterzeichnen\xa0– ohne rechtlichen Beistand. Sucht der Schulleiter Hilfe bei der Kommune, dann verweist die ihn ans Land, und das Land verweist wiederum an die Kommune. Ein Lehrer, der die Lernsoftware dann dennoch einsetzt, der steht mit einem Bein im Gefängnis. Das ist ein einziger Albtraum. Die Verantwortung dafür tragen wir als Gesetzgeber. Wir müssen endlich Klarheit schaffen beim Datenschutz.\n\n({4})\n\nFünftens. Die Nutzungsdaten aus Lernprogrammen ermöglichen eine Revolution in der Bildungsforschung. Zum Vergleich: Die PISA-Studien beruhen auf Stichproben von etwa 5\xa0000\xa0Schülern in Deutschland, die alle drei Jahre erhoben werden. Künftig stehen Lerndaten von über 10\xa0Millionen Schülern zur Verfügung\xa0– für jeden Jahrgang, jedes Fach, jeden Tag. Daran lässt sich dann glasklar ablesen, wie Lerninhalte am erfolgreichsten vermittelt werden\xa0– als Text, Audio oder Bild. Diesen großen Wissensschatz nicht zu nutzen, das wäre grob fahrlässig. Doch auch dafür braucht es klare Vorgaben zum Schutz sensibler Daten.\n\n({5})\n\nMeine Damen und Herren, der vorliegende Digitalpakt kümmert sich nur um die technische Infrastruktur; aber das reicht nicht. Wir brauchen einen Digitalpakt\xa02.0; sonst wird technische Infrastruktur im Wert von über 5\xa0Milliarden Euro veraltet sein, bevor sie überhaupt eingesetzt werden kann. Das müssen wir unbedingt verhindern. Frau Karliczek, beginnen Sie jetzt mit den Verhandlungen.\n\nVielen Dank.\n\n({6})',
#  '2019-05-16',
#  101,
#  19,
#  11004617,
#  '\n\nHerr Präsident! Liebe Kolleginnen und Kollegen! Ich freue mich, dass wir heute erneut über den DigitalPakt Schule diskutieren, und heute nicht mehr als Vorhaben, sondern als beschlossenes Projekt. Die Länder haben die Verwaltungsvereinbarung unterzeichnet. Es ist begonnen worden, die Förderkriterien entsprechend auszuarbeiten, und die ersten Gelder können noch in diesem Jahr fließen.\n\n({0})\n\nDie Schulen freu
süd, Ost und West, an die kleinen und die großen. Wir brauchen alle, und wir laden alle dazu ein, an einem stärkeren, solidarischeren, handlungsfähigeren Europa mitzuarbeiten. Dieses Angebot steht.\n\nIch will nur einige wenige Bereiche benennen, wo es notwendig ist, dass wir noch enger zusammenarbeiten, dass wir Vorurteile und Klischees überwinden und dass wir uns gemeinsam an die Arbeit machen. Klimaschutz ist ein wichtiges Thema. In der vergangenen Woche hat es dazu auch eine kritische Diskussion, nicht zuletzt zwischen Deutschland und Frankreich, gegeben. Am Ende hängt es aber maßgeblich von uns Europäerinnen und Europäern ab. Schaffen wir es, Mut zu machen und zu zeigen, dass der Satz von Donald Trump, dass Klimaschutz ein Jobkiller ist, nicht stimmt?\n\n({2})\n\nDeshalb müssen wir einerseits das Angebot der jungen Leute ernst nehmen, uns kritisch zu unterstützen, aber eben auch die Arbeitnehmerinnen und Arbeitnehmer, die sich Sorgen um ihre Arbeitsplätze machen, mitnehmen. Das können Deutschland und Frankreich in enger Zusammenarbeit mit anderen. Das gilt auch für das soziale Europa.\n\nIm Aachener Vertrag haben wir ein klares Bekenntnis dazu abgegeben, dass Europa sozialer werden muss, dass wir unsere Bürgerinnen und Bürger schützen müssen. Es liegt eine Reihe von Vorschlägen auf dem Tisch: Mindestlöhne überall, soziale Grundsicherung überall, endlich eine gerecht e und faire Besteuerung der international und europaweit agierenden Konzerne.\n\n({3})\n\nDas geht nur, wenn Deutschland und Frankreich zusammenarbeiten und wenn wir uns alle am Riemen reißen und diese Zusammenarbeit mit Leben erfüllen.\n\n({4})\n\nEin letzter Punkt\xa0– ich weiß, dass es viele Kolleginnen und Kollegen gibt, die das mit großem Engagement verfolgen\xa0– ist die Zusammenarbeit in den sogenannten Grenzregionen. Am Ende geht es vor allem darum: Gelingt es uns, dass die Grenze im Alltag der Menschen gänzlich unsichtbar wird? In den Bereichen Gesundheit, Brandschutz, Sicherheit, Bildung, Qualifizierung wollen wir als Bundesländer, als Kommunen, als Kreise, als Regionen und Departements deutlich machen: Es gelingt, und Europa wird besser, wenn Grenzen verschwinden.\n\nDeshalb bitte ich Sie im Namen der Bundesregierung um Ihre engagierte Debatte\xa0– die kommt ja gleich noch\xa0– und um Ihre Un ...
#  '2019-05-16',
#  101,
#  19,
#  11003124,
#  '\n\nGestatten Sie eine Zwischenfrage?',
#  '2019-05-16',
#  101,
#  19,
#  11001938,
#  '\n\nNächster Redner ist der Kollege Alexander Dobrindt, CDU/CSU.\n\n({0})',
#  '2019-05-16',
#  101,
#  19,
#  11001938,
#  '\n\nJetzt erteile ich das Wort dem Fraktionsvorsitzenden der Linken, Dr.\xa0Dietmar Bartsch.\n\n({0})',
#  '2019-05-16',
#  101,
#  19,
#  11003034,
. Es ist eine atmende Verfassung, und als solche war sie auch angelegt. Sie hat auch Antworten auf Fragen, die sich 1949 noch gar nicht gestellt haben.\n\nDennoch muss diese Verfassung auch immer wieder auf die Höhe der Zeit gebracht werden. Ich nenne exemplarisch, dass das Grundgesetz 1949 die damals modernsten bekannten Medientechnologien bereits erwähnt hat, nämlich den Buchdruck, die Zeitschriften und den Rundfunk. Wer heute als junger Mensch in das Grundgesetz schaut, findet zwar die modernsten Medientechnologien des 19. und 20.\xa0Jahrhunderts darin erwähnt und beachtet, aber eben nicht die modernste Medientechnologie des 21.\xa0Jahrhunderts, nämlich das Internet. Und wir sollten auch in dieser Frage unsere Verfassung auf die Höhe der Zeit bringen. Die Klärung solcher Fragen sollten wir nicht der Interpretation des Verfassungsgerichts überlassen.\n\n({4})\n\nIm Zentrum, liebe Kolleginnen und Kollegen, des Grundgesetzes, unserer Werteordnung stehen die Grundrechte, und wie Carlo Schmid sagte: „Die Grundrechte müssen das Grundgesetz regieren“. Das mag selbstverständlich erscheinen, ist es aber nicht. Nehmen wir nur die aktuelle Debatte um die Enteignung von Wohnungsbauunternehmen\xa0– ich will jetzt gar nicht im Einzelnen in die Baupolitik einsteigen\xa0–; es ist eben eine doch auch gesellschafts- und verfassungspolitische Debatte. D ...
#  '2019-05-16',
#  101,
#  19,
#  11003132,
# ...
#  '2019-05-16',
#  101,
#  19,
#  11003820,
#  '\n\nVielen Dank.\xa0– Nächster Redner ist der Kollege Dr.\xa0Jens Brandenburg für die Fraktion der FDP.\n\n({0})',
#  '2019-05-16',
#  101,
#  19,
#  11004676,
#  '\n\nHerr Präsident! Frau Ministerin! Liebe Kolleginnen und Kollegen! Was Sie heute beschließen wollen, das ist eine Kapitulation vor dem Status quo. Für den Inflationsausgleich, der längst überfällig ist, mögen Sie sich heute noch feiern.\n\n({0})\n\nSie werden spätestens morgen merken, dass Ihnen auch mit diesem Inflationsausgleich einmal mehr die Trendumkehr im BAföG nicht gelingen wird.\n\n({1})\n\nDas ist kein verantwortungsvolles Regierungshandeln. Das ist Selbstbetrug in Dauerschleife, meine Damen und Herren.\n\nAls einzige Fraktion haben wir Freie Demokraten einen wirklich strukturellen und finanzierbaren Reformvorschlag vorgelegt. Wir wollen ein elternunabhängiges Baukasten-BAföG, das mit der Antragsbürokratie und mit finanzieller Unsicherheit Schluss macht; ein Modell mit flexiblen Zuschuss- und Darlehensbausteinen, das Studierenden in jeder Situation weiterhilft.\n\n({2})\n\nErwartungsgemäß hat Ihre Kritik nicht lange auf sich warten lassen:\n\n({3})\n\n„Das haben wir ja noch nie gemacht.“ Man könne doch erwachsene Studierende nicht unabhängig von ihren Eltern betrachten. Überhaupt: Es sei ja unzumutbar, wenn auf einmal dieselben Regeln für alle gelten.\xa0– Solche Abwehrreflexe sind ja bei großen Reformvorschlägen nichts Neues. Aber Sie sollten doch zumindest wissen, welche Menschen Sie damit weiterhin im Regen stehen lassen. Fünf Beispiele:\n\nErstens. Martin bekommt kein BAföG, weil seine Eltern, Facharbeiter, auf dem Papier zu reich sind. Sie müssen ihr Haus noch abbezahlen und schaffen es mit großer Mühe, jeden Monat 300\xa0Euro für ihren Sohn zusammenzukratzen.\xa0– Sie sagen: Dann sollen sie doch ihr Haus verkaufen.\n\n({4})\n\nWir sagen: Martin verdient unsere Unterstützung.\n\n({5})\n\nZweites Beispiel. Manuela möchte gerne Sozialpäda\xadgogik studieren. Ihre Eltern unterstützen das nicht. Sie soll schließlich später die Zahnarztpraxis übernehmen.\xa0– Sie sagen: Dann kann sie doch ihre Eltern auf Unterhalt verklagen. Wir sagen: Manuela ist eine eigenständige Persönlichkeit, deren Wahl des Studienfaches nicht von der Unterstützungsbereitschaft ihrer Eltern abhängen darf.\n\n({6})\n\nDrittens. Daniel möchte sein Studium ganz ohne Darlehen finanzieren. Ihm ist egal, dass er dieses BAföG-Darlehen später überhaupt erst als Gutverdiener zurückzahlen müsste.\n\n({7})\n\n–\xa0Ich verstehe ja die Aufregung. Es freut mich ja, dass wir endlich was zu diskutieren haben.\n\n({8})\n\nBei diesem Beispiel mit Daniel sagen Sie ganz konkret: Ohne Darlehensanteil gibt es eben auch kein BAföG. Wir sagen: Lieber Daniel, mit einem überschaubaren Nebenjob und unseren Zuschussbausteinen sollte es möglich sein, dass du dein Studium ganz ohne Darlehensanteil finanzierst.\n\n({9})\n\nViertens. Auch Tanja erhält kein BAföG. Mit mehreren Nebenjobs hält sie sich gerade so über Wasser. Jetzt werden auf einen Schlag der Semesterbeitrag, die Kosten für das Semesterticket und eine hohe Nachzahlung zu den Nebenkosten fällig. Das wirft Tanja völlig aus der Bahn.\xa0– Sie sagen: Pech gehabt! Die SPD will ja kein „Verschuldungsprogramm“.\n\n({10})\n\nWir sagen: Das erst bei gutem Einkommen rückzahlbare zinsfreie BAföG-Darlehen, das genau als Puffer für solche Situationen zur Verfügung stehen sollte, wollen wir künftig allen Studierenden bereitstellen.\n\nFünftens. Lara arbeitet neben ihrem Studium mehr als 15\xa0Stunden die Woche, um das Studium zu finanzieren.\n\n({11})\n\nKeine Seltenheit. Jeder vierte Nicht-BAföG-Empfänger macht das heute schon so. Sie sagen: Diese Studierenden sind nicht bedürftig. Wir sagen: Lasst uns doch die unterstützen, die wirklich darauf angewiesen sind,\n\n({12})\n\nund Lara in die Lage versetzen, ihr Studium zu finanzieren und gleichzeitig ihre Nebentätigkeit im Umfang auf den Samstag zu reduzieren.\n\nSie sehen also: Anders als viele andere hier im Raum fordern und versprechen wir nicht immer mehr Geld für wenige, sondern handfeste Bildungschancen für jeden. Sie können es sich einfach machen und weiter auf forma ...
#  '2019-05-16',
#  101,
#  19,
#  11003820,
#  '\n\nVielen Dank.\xa0– Nächste Rednerin ist für die Fraktion Die Linke die Kollegin Nicole Gohlke.\n\n({0})',
#  '2019-05-16',
#  101,
#  19,
#  11004041,
öglichen. Ja, gerne! Das ist zwar der nächste Tu-nix-Minister. Aber man muss beides zusammendenken: Natürlich brauchen wir den Wohnheimbau. Aber wir brauchen auch eine vernünftige Wohnförderung im Rahmen des BAföG. Wenn Sie einerseits das Wohngeld erhöhen und andererseits den Studis nur eine Pauschale geben, dann reicht das nicht. Wir brauchen eine regionale Staffelung, damit auch das Arbeiterkind aus einem einkommensarmen Elternhaus an der Exzellenzuni und in teuren Unistädten leben und wohnen kann. Wohnen darf auch für Studis kein Luxusgut werden.\n\n({4})\n\nJetzt versetzen Sie sich mal in einen 17-Jährigen oder eine 17-Jährige, der bzw. die ein kleines Taschengeld aus dem armen Elternhaus bekommen und hören: Wenn man den BAföG-Höchstsatz bekommt, kann man bis zu 10\xa0000\xa0Euro Schulden nach dem Studium haben.\xa0– Dann ist doch völlig klar, dass man erst gar kein BAföG beantragt, weil man Verschuldungssorgen hat und sich nicht zutraut, das zu stemmen. Wer will denn 10\xa0000\xa0Euro zurückzahlen müssen? Deshalb muss die Verschuldungsobergrenze runter. Auch das beantragen wir heute, weil wir einen Einstieg in unser Zwei-Säulen-Modell der Studienfinanzierung wollen. Wir sollten zu Vollzuschüssen zurückkehren, wie das in den 70er-Jahren der Fall war, wo das BAföG noch richtig funktionierte und zum Leben reichte.\n\n({5})\n\nWirklich unverschämt ist, dass Sie einmal mehr die Datenlage manipulieren. Deshalb beantragen wir heute die zweite namentliche Abstimmung: Der BAföG-Bericht wäre 2019 fällig. Wir wollen diese Daten. Diese werden brutal sein. Aber Sie machen in einem Spiegelstrich eine Verschiebung auf 2021. Das heißt, erst nach der nächsten Bundestagswahl sieht man, wie viele Studierende wieder aus dem BAföG-Berechtigtenkreis herausfliegen. Das ist keine seriöse Politik. Der BAföG-Bericht muss im Zwei-Jahres-Turnus erfolgen, dami ...
#  '2019-05-16',
#  101,
#  19,
#  11003820,
#  '\n\nVielen Dank.\xa0– Nächster Redner ist für die Fraktion der CDU/CSU der Kollege Dr.\xa0Stefan Kaufmann.\n\n({0})',
#  '2019-05-16',
#  ...]

# %%
len(plenar16)
# Out:
# 1870

# %%
import spacy
import re
import torch
import spacy_transformers
import nltk
from spacytextblob.spacytextblob import SpacyTextBlob
from textblob import TextBlob
from textblob.sentiments import NaiveBayesAnalyzer
nlp = spacy.load('de_dep_news_trf')
nlp.add_pipe('spacytextblob')

# %%
nlp.pipeline
# Out:
# [('transformer',
#   <spacy_transformers.pipeline_component.Transformer at 0x1eb8c1c5370>),
#  ('tagger', <spacy.pipeline.tagger.Tagger at 0x1eb8c1c5130>),
#  ('morphologizer',
#   <spacy.pipeline.morphologizer.Morphologizer at 0x1eb8c1c5430>),
#  ('parser', <spacy.pipeline.dep_parser.DependencyParser at 0x1eb8c097220>),
#  ('lemmatizer',
#   <spacy.pipeline.edit_tree_lemmatizer.EditTreeLemmatizer at 0x1eb8c1c5730>),
#  ('attribute_ruler',
#   <spacy.pipeline.attributeruler.AttributeRuler at 0x1eb8c20a010>),
#  ('spacytextblob',
#   <spacytextblob.spacytextblob.SpacyTextBlob at 0x1eb8c079a10>)]

# %%
#schleifen um an drittes element, zweites element zu kommen, weitere verschachtlung um an jeweils sätze zukommen

beitraege = []


for i in range(3, len(plenar16), 5): 
    doc = nlp(plenar16[i])
    beitraege.append(doc.text)

for beitrag in beitraege:
    print("_____________________________________________________________________")
    print(beitrag)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[15], line 7
#       3 beitraege = []
#       6 for i in range(3, len(plenar16), 5):
# ----> 7     doc = nlp(plenar16[i])
#       8     beitraege.append(doc.text)
#      10 for beitrag in beitraege:
#
# File ~\anaconda3\Lib\site-packages\spacy\language.py:1011, in Language.__call__(self, text, disable, component_cfg)
#    1009     error_handler = proc.get_error_handler()
#    1010 try:
# -> 1011     doc = proc(doc, **component_cfg.get(name, {}))  # type: ignore[call-arg]
#    1012 except KeyError as e:
#    1013     # This typically happens if a component is not initialized
#    1014     raise ValueError(Errors.E109.format(name=name)) from e
#
# File ~\anaconda3\Lib\site-packages\spacy_transformers\pipeline_component.py:192, in Transformer.__call__(self, doc)
#     182 """Apply the pipe to one document. The document is modified in place,
#     183 and returned. This usually happens under the hood when the nlp object
#     184 is called on a text and all components are applied to the Doc.
#    (...)
#     189 DOCS: https://spacy.io/api/transformer#call
#     190 """
#     191 install_extensions()
# --> 192 outputs = self.predict([doc])
#     193 self.set_annotations([doc], outputs)
#     194 return doc
#
# File ~\anaconda3\Lib\site-packages\spacy_transformers\pipeline_component.py:229, in Transformer.predict(self, docs)
#     227     activations = FullTransformerBatch.empty(len(docs))
#     228 else:
# --> 229     activations = self.model.predict(docs)
#     230 return activations
#
# File ~\anaconda3\Lib\site-packages\thinc\model.py:315, in Model.predict(self, X)
#     311 def predict(self, X: InT) -> OutT:
#     312     """Call the model's `forward` function with `is_train=False`, and return
#     313     only the output, instead of the `(output, callback)` tuple.
#     314     """
# --> 315     return self._func(self, X, is_train=False)[0]
#
# File ~\anaconda3\Lib\site-packages\spacy_transformers\layers\transformer_model.py:199, in forward(model, docs, is_train)
#     193     align = get_alignment(
#     194         flat_spans, wordpieces.strings, tokenizer.all_special_tokens
#     195     )
#     196 wordpieces, align = truncate_oversize_splits(
#     197     wordpieces, align, tokenizer.model_max_length
#     198 )
# --> 199 model_output, bp_tensors = transformer(wordpieces, is_train)
#     200 if "logger" in model.attrs:
#     201     log_gpu_memory(model.attrs["logger"], "after forward")
#
# File ~\anaconda3\Lib\site-packages\thinc\model.py:291, in Model.__call__(self, X, is_train)
#     288 def __call__(self, X: InT, is_train: bool) -> Tuple[OutT, Callable]:
#     289     """Call the model's `forward` function, returning the output and a
#     290     callback to compute the gradients via backpropagation."""
# --> 291     return self._func(self, X, is_train=is_train)
#
# File ~\anaconda3\Lib\site-packages\thinc\layers\pytorchwrapper.py:219, in forward(model, X, is_train)
#     216 convert_outputs = model.attrs["convert_outputs"]
#     218 Xtorch, get_dX = convert_inputs(model, X, is_train)
# --> 219 Ytorch, torch_backprop = model.shims[0](Xtorch, is_train)
#     220 Y, get_dYtorch = convert_outputs(model, (X, Ytorch), is_train)
#     222 def backprop(dY: Any) -> Any:
#
# File ~\anaconda3\Lib\site-packages\thinc\shims\pytorch.py:92, in PyTorchShim.__call__(self, inputs, is_train)
#      90     return self.begin_update(inputs)
#      91 else:
# ---> 92     return self.predict(inputs), lambda a: ...
#
# File ~\anaconda3\Lib\site-packages\thinc\shims\pytorch.py:110, in PyTorchShim.predict(self, inputs)
#     108 with torch.no_grad():
#     109     with torch.cuda.amp.autocast(self._mixed_precision):
# --> 110         outputs = self._model(*inputs.args, **inputs.kwargs)
#     111 self._model.train()
#     112 return outputs
#
# File ~\anaconda3\Lib\site-packages\torch\nn\modules\module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\torch\nn\modules\module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File ~\anaconda3\Lib\site-packages\transformers\models\bert\modeling_bert.py:1020, in BertModel.forward(self, input_ids, attention_mask, token_type_ids, position_ids, head_mask, inputs_embeds, encoder_hidden_states, encoder_attention_mask, past_key_values, use_cache, output_attentions, output_hidden_states, return_dict)
#    1011 head_mask = self.get_head_mask(head_mask, self.config.num_hidden_layers)
#    1013 embedding_output = self.embeddings(
#    1014     input_ids=input_ids,
#    1015     position_ids=position_ids,
#    (...)
#    1018     past_key_values_length=past_key_values_length,
#    1019 )
# -> 1020 encoder_outputs = self.encoder(
#    1021     embedding_output,
#    1022     attention_mask=extended_attention_mask,
#    1023     head_mask=head_mask,
#    1024     encoder_hidden_states=encoder_hidden_states,
#    1025     encoder_attention_mask=encoder_extended_attention_mask,
#    1026     past_key_values=past_key_values,
#    1027     use_cache=use_cache,
#    1028     output_attentions=output_attentions,
#    1029     output_hidden_states=output_hidden_states,
#    1030     return_dict=return_dict,
#    1031 )
#    1032 sequence_output = encoder_outputs[0]
#    1033 pooled_output = self.pooler(sequence_output) if self.pooler is not None else None
#
# File ~\anaconda3\Lib\site-packages\torch\nn\modules\module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\torch\nn\modules\module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File ~\anaconda3\Lib\site-packages\transformers\models\bert\modeling_bert.py:610, in BertEncoder.forward(self, hidden_states, attention_mask, head_mask, encoder_hidden_states, encoder_attention_mask, past_key_values, use_cache, output_attentions, output_hidden_states, return_dict)
#     601     layer_outputs = torch.utils.checkpoint.checkpoint(
#     602         create_custom_forward(layer_module),
#     603         hidden_states,
#    (...)
#     607         encoder_attention_mask,
#     608     )
#     609 else:
# --> 610     layer_outputs = layer_module(
#     611         hidden_states,
#     612         attention_mask,
#     613         layer_head_mask,
#     614         encoder_hidden_states,
#     615         encoder_attention_mask,
#     616         past_key_value,
#     617         output_attentions,
#     618     )
#     620 hidden_states = layer_outputs[0]
#     621 if use_cache:
#
# File ~\anaconda3\Lib\site-packages\torch\nn\modules\module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\torch\nn\modules\module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File ~\anaconda3\Lib\site-packages\transformers\models\bert\modeling_bert.py:495, in BertLayer.forward(self, hidden_states, attention_mask, head_mask, encoder_hidden_states, encoder_attention_mask, past_key_value, output_attentions)
#     483 def forward(
#     484     self,
#     485     hidden_states: torch.Tensor,
#    (...)
#     492 ) -> Tuple[torch.Tensor]:
#     493     # decoder uni-directional self-attention cached key/values tuple is at positions 1,2
#     494     self_attn_past_key_value = past_key_value[:2] if past_key_value is not None else None
# --> 495     self_attention_outputs = self.attention(
#     496         hidden_states,
#     497         attention_mask,
#     498         head_mask,
#     499         output_attentions=output_attentions,
#     500         past_key_value=self_attn_past_key_value,
#     501     )
#     502     attention_output = self_attention_outputs[0]
#     504     # if decoder, the last output is tuple of self-attn cache
#
# File ~\anaconda3\Lib\site-packages\torch\nn\modules\module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\torch\nn\modules\module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File ~\anaconda3\Lib\site-packages\transformers\models\bert\modeling_bert.py:425, in BertAttention.forward(self, hidden_states, attention_mask, head_mask, encoder_hidden_states, encoder_attention_mask, past_key_value, output_attentions)
#     415 def forward(
#     416     self,
#     417     hidden_states: torch.Tensor,
#    (...)
#     423     output_attentions: Optional[bool] = False,
#     424 ) -> Tuple[torch.Tensor]:
# --> 425     self_outputs = self.self(
#     426         hidden_states,
#     427         attention_mask,
#     428         head_mask,
#     429         encoder_hidden_states,
#     430         encoder_attention_mask,
#     431         past_key_value,
#     432         output_attentions,
#     433     )
#     434     attention_output = self.output(self_outputs[0], hidden_states)
#     435     outputs = (attention_output,) + self_outputs[1:]  # add attentions if we output them
#
# File ~\anaconda3\Lib\site-packages\torch\nn\modules\module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\torch\nn\modules\module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File ~\anaconda3\Lib\site-packages\transformers\models\bert\modeling_bert.py:306, in BertSelfAttention.forward(self, hidden_states, attention_mask, head_mask, encoder_hidden_states, encoder_attention_mask, past_key_value, output_attentions)
#     304     value_layer = torch.cat([past_key_value[1], value_layer], dim=2)
#     305 else:
# --> 306     key_layer = self.transpose_for_scores(self.key(hidden_states))
#     307     value_layer = self.transpose_for_scores(self.value(hidden_states))
#     309 query_layer = self.transpose_for_scores(mixed_query_layer)
#
# File ~\anaconda3\Lib\site-packages\torch\nn\modules\module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\torch\nn\modules\module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File ~\anaconda3\Lib\site-packages\torch\nn\modules\linear.py:116, in Linear.forward(self, input)
#     115 def forward(self, input: Tensor) -> Tensor:
# --> 116     return F.linear(input, self.weight, self.bias)
#
# KeyboardInterrupt:

# %%
sentimentwert = 0
for beitrag in beitraege:
    doc = nlp(beitrag)
    
    for span in doc.sents:
        #doc = nlp(beitrag)
        blob = TextBlob(span.text, analyzer = NaiveBayesAnalyzer())
        print(span, blob.sentiment)
        print (' ')
# Out:
# Sehr geehrter Herr Präsident! Sentiment(classification='pos', p_pos=0.5, p_neg=0.5)
#
# Liebe Kolleginnen und Kollegen! Sentiment(classification='pos', p_pos=0.5, p_neg=0.5)
#
# Unser Grundgesetz ist ein Segen der deutschen Geschichte, mehr als die Summe seiner Artikel, mehr als ein historisches Dokument. Sentiment(classification='neg', p_pos=0.3645833333333331, p_neg=0.6354166666666669)
#
# Das Grundgesetz hat die Menschen in Deutschland für sich gewonnen.
#
# ({0})
#
# Meine Damen und Herren, das Grundgesetz ist heute eine lebendige Verfassung für über 80 Millionen Menschen in unserem Land, und es hat die Menschen im Laufe der Geschichte zweimal für sich gewonnen.
#
#  Sentiment(classification='pos', p_pos=0.8135213830409583, p_neg=0.1864786169590412)
#
# Unser Grundgesetz ist entstanden nach nationalsozialistischer Diktatur, nach Krieg und Zerstörung. Sentiment(classification='pos', p_pos=0.5, p_neg=0.5)
#
# Deutschland war damals seiner geistigen Grundlage beraubt, moralisch gescheitert und entkernt. Sentiment(classification='pos', p_pos=0.6620879120879126, p_neg=0.3379120879120879)
#
# Und es waren einige wenige Entscheidungsträger im Parlamentarischen Rat, die in dieser Stunde mit dem Grundgesetz eine neue Werteordnung geschaffen haben und damit der Bundesrepublik einen ethisch-moralischen, wirtschaftlichen und gesellschaftlichen Neuanfang ermöglicht haben. Sentiment(classification='pos', p_pos=0.8092113332515632, p_neg=0.190788666748436)
#
# Was damals einer kleinen Gruppe gelungen ist, wurde dann zu einer gemeinsamen, einer geteilten Überzeugung der Menschen in unserem Land. Sentiment(classification='neg', p_pos=0.17327262077313413, p_neg=0.8267273792268661)
#
# Aus einem Projekt der wenigen wurde eine Werteordnung für Millionen. Sentiment(classification='neg', p_pos=0.38888888888888884, p_neg=0.6111111111111108)
#
# Das ist ein Grund, warum wir heute feiern. Sentiment(classification='pos', p_pos=0.9166666666666673, p_neg=0.08333333333333334)
#
#
#
# Aber das Grundgesetz hat auch ein zweites Mal die Menschen für sich gewonnen: vor 30 Jahren, als die Menschen in der DDR bei den Montagsdemonstrationen auf die Straßen gingen. Sentiment(classification='pos', p_pos=0.8100488133310888, p_neg=0.1899511866689108)
#
# Denn diese Demonstrationen waren im Kern ja auch ein Ruf nach dem Grundgesetz, nach seinen Werten und seiner freiheitlich-demokratischen Grundordnung. Sentiment(classification='pos', p_pos=0.5, p_neg=0.5)
#
# In all den Jahren des Unrechts der DDR war es immer auch der dringende Appell der Präambel, „die Einheit und Freiheit Deutschlands zu vollenden“, die den Menschen im Osten Hoffnung gegeben hat, meine Damen und Herren.
#
# ({1})
#
# Wenn wir heute 70 Jahre Grundgesetz feiern, dann feiern wir auch, dass Demokratie, Meinungsfreiheit und Menschenwürde stärker sind als Diktatur, als Stacheldraht, als Schießbefehl. Sentiment(classification='neg', p_pos=0.4338335754641245, p_neg=0.5661664245358768)
#
# Dieses Grundgesetz hat Mauern eingerissen und Menschen zusammengeführt. Sentiment(classification='neg', p_pos=0.40322580645161266, p_neg=0.596774193548387)
#
# Heute ist unser Grundgesetz die gemeinsame Klammer, eine Klammer der Freiheit, der Gleichheit, der Brüderlichkeit, eine Klammer für Einigkeit, für Recht und Freiheit. Sentiment(classification='neg', p_pos=0.3645833333333331, p_neg=0.6354166666666669)
#
# Diese Klammer ist nicht nur so stark, weil sie uns als Bürger schützt, sondern vor allem, weil Bürger unsere Verfassung schützen. Sentiment(classification='pos', p_pos=0.9615384615384616, p_neg=0.0384615384615384)
#
# Das kann man zu Recht auch Patriotismus nennen. Sentiment(classification='pos', p_pos=0.9259008136381246, p_neg=0.07409918636187521)
#
#
#
# ({2})
#
#  Sentiment(classification='pos', p_pos=0.5, p_neg=0.5)
#
# Mit dieser Klammer bildet das Grundgesetz übrigens auch die Voraussetzung für gelungene Integration. Sentiment(classification='pos', p_pos=0.9862316296333457, p_neg=0.013768370366654962)
#
# Wer integrieren will, der muss auch wissen, wohin – und wir wissen, wohin: in die Werteordnung unseres Grundgesetzes und seiner Grundsätze für das Zusammenleben in Deutschland. Sentiment(classification='pos', p_pos=0.87694221631021, p_neg=0.1230577836897901)
#
# Dieses Grundgesetz grenzt niemanden aus. Sentiment(classification='pos', p_pos=0.5, p_neg=0.5)
#
# Es ist ein Grundgesetz für alle Menschen, egal welchen Glaubens, welcher Herkunft, welcher Kultur, welcher Tradition.
#
# ({3})
#
#  Sentiment(classification='pos', p_pos=0.6929824561403507, p_neg=0.3070175438596492)
#
# Dieses Grundgesetz garantiert allen Menschen in Deutschland Rechte und Privilegien, aber es fordert auch etwas ein. Sentiment(classification='pos', p_pos=0.5902777777777775, p_neg=0.4097222222222221)
#
# Genau diese Erwartung einzulösen, ist der Ausgangspunkt für eine gelungene Integration. Sentiment(classification='pos', p_pos=0.5147058823529416, p_neg=0.48529411764705804)
#
#
#
# ({4})
#
# Der Parlamentarische Rat hat als Grundlage des Wertefundaments unseres Grundgesetzes eine christliche Prägung verankert. Sentiment(classification='pos', p_pos=0.6875451589595366, p_neg=0.31245484104046267)
#
# In „Verantwortung vor Gott und den Menschen“ – so laute n die ersten Worte unserer Verfassung. Sentiment(classification='neg', p_pos=0.4741379310344821, p_neg=0.5258620689655165)
#
# Genau das ist der Ausgangspunkt für vieles, was folgt: Die Würde des Menschen, die Freiheit und Gleichheit, das Asylrecht, die Subsidiarität, der Schutz des Eigentums – diese Werte gründen auf der christlichen Soziallehre. Sentiment(classification='pos', p_pos=0.9481541463066202, p_neg=0.0518458536933816)
#
# Deswegen will ich an dieser Stelle auch denen in Erinnerung rufen, die in einer Leitkulturdebatte gerne meinen, dass eine spezifische deutsche Kultur nicht identifizierbar sei und deswegen das Grundgesetz der alleinige Maßstab sei: Sentiment(classification='pos', p_pos=0.87694221631021, p_neg=0.1230577836897901)
#
# Ja, das Grundgesetz ist der Maßstab. Sentiment(classification='pos', p_pos=0.8750000000000009, p_neg=0.125)
#
# Aber das ist kein Argument gegen eine Leitkultur, es ist gerade die Bestätigung unserer christlichen Werteordnung, meine Damen und Herren.
#
# ({5})
#
#  Sentiment(classification='pos', p_pos=0.9626682986536101, p_neg=0.037331701346389155)
#
# Eine zentrale Garantie des Grundgesetzes, das sich übrigens unmittelbar auf unser tägliches Miteinander auswirkt, ist die Meinungsfreiheit. Sentiment(classification='pos', p_pos=0.9674840085287847, p_neg=0.03251599147121534)
#
# Sie ist der klare Ausgangspunkt einer offenen, positiven politischen Debattenkultur, aber übrigens auch eine tägliche Verpflichtung für uns alle, Meinungsfreiheit nicht auf die eigene Meinung zu verengen, Meinung nicht aus der Debatte auszugrenzen, sondern sie in die Mitte der Debatte zu holen, sie zuzulassen, zuzuhören, sich Diskussionen zu stellen und zu versuchen, mit Argumenten zu überzeugen, nicht mit Lautstärke. Sentiment(classification='pos', p_pos=0.7131661442006269, p_neg=0.28683385579937315)
#
#
#
# ({6})
#
# Aber auch das sage ich klar und deutlich: Sentiment(classification='pos', p_pos=0.9519230769230771, p_neg=0.04807692307692298)
#
# Die in unserem Grundgesetz verankerte Meinungsfreiheit kennt auch Grenzen. Sentiment(classification='neg', p_pos=0.47413793103448265, p_neg=0.5258620689655171)
#
# Und die Grenzen verlaufen nicht dort, wo die eigene Meinung endet, sondern dort, wo die Meinungsfreiheit missbraucht wird, um die verfassungsrechtliche Ordnung anzugreifen oder zu zerstören oder den Parlamentarismus zu untergraben. Sentiment(classification='neg', p_pos=0.4741379310344821, p_neg=0.5258620689655178)
#
#
#
#  Sentiment(classification='pos', p_pos=0.5, p_neg=0.5)
#
# Liebe Kolleginnen und Kollegen, wer die Religionsfreiheit abschaffen will und wer den Nationalsozialismus relativiert, der kann sich hier nicht hinstellen und sagen, er sei ein Freund des Grundgesetzes. Sentiment(classification='pos', p_pos=0.6602714421609192, p_neg=0.3397285578390814)
#
# Er ist das Gegenteil.
#
# ({7})
#
#  Sentiment(classification='pos', p_pos=0.9166666666666673, p_neg=0.08333333333333334)
#
# Wer immer wieder Wege zum Kommunismus sucht und wer das Unrecht der DDR verharmlost, der kann sich hier nicht hinstellen und sagen, er sei ein Freund des Grundgesetzes. Sentiment(classification='pos', p_pos=0.9545454545454548, p_neg=0.045454545454545484)
#
# Er ist das Gegenteil, liebe Freunde.
#
# ({8})
#
#  Sentiment(classification='pos', p_pos=0.9166666666666673, p_neg=0.08333333333333334)
#
# Das Grundgesetz – das ist ein bedeutender Aspekt – ist eine zutiefst föderale Verfassung. Sentiment(classification='pos', p_pos=0.9166666666666673, p_neg=0.08333333333333334)
#
# Dafür formuliert das Grundgesetz sogar eine Ewigkeitsgarantie. Sentiment(classification='pos', p_pos=0.9166666666666673, p_neg=0.08333333333333334)
#
# Heute wissen wir: Der Föderalismus ist ein absolutes Erfolgsmodell. Sentiment(classification='pos', p_pos=0.6562499999999998, p_neg=0.3437499999999998)
#
# Er ist zwar nicht jeden Tag immer gleich einfach zu erfüllen, aber dass politische Entscheidungen nicht nur in Berlin, sondern auch in den Landeshauptstädten getroffen werden, das stärkt unsere Demokratie, meine Damen und Herren, und schwächt sie nicht.
#
# ({9})
#
# In der Präambel unseres Grundgesetzes steht neben dem Gottesbezug übrigens ein weiterer sehr bemerkenswerter Satz: „in einem vereinten Europa dem Frieden der Welt zu dienen“. Sentiment(classification='pos', p_pos=0.9600917431192645, p_neg=0.039908256880733864)
#
# Das ist der Auftrag, den die Mütter und Väter des Grundgesetzes uns mit auf den Weg gegeben haben, ein Auftrag, 1949 geschrieben. Sentiment(classification='pos', p_pos=0.9723481414324564, p_neg=0.027651858567542906)
#
# In einem vereinten Europa dem Frieden der Welt zu dienen – vier Jahre nach Krieg und Zerstörung, acht Jahre vor Gründung der Europäischen Wirtschaftsgemeinschaft, dieses klare Bekenntnis zur europäischen Einheit, weil die Mütter und Väter unseres Grundgesetzes wussten, was heute genauso gilt: Sentiment(classification='pos', p_pos=0.734811376766915, p_neg=0.2651886232330841)
#
# Ein starkes Deutschland gibt es nur in einem starken Europa. Sentiment(classification='pos', p_pos=0.5, p_neg=0.5)
#
# Unsere nationale Souveränität, unseren Wohlstand, all das können wir nicht alleine, sondern nur gemeinsam in Europa sichern. Sentiment(classification='pos', p_pos=0.9173309866445798, p_neg=0.08266901335541975)
#
# Das ist heute genauso aktuell wie damals. Sentiment(classification='pos', p_pos=0.9166666666666673, p_neg=0.08333333333333334)
#
# Für dieses Europa sollten wir gemeinsam eintreten. Sentiment(classification='pos', p_pos=0.5, p_neg=0.5)
#
# Das Grundgesetz hat die Menschen für sich gewonnen. Sentiment(classification='pos', p_pos=0.8701530318720526, p_neg=0.12984696812794844)
#
# Europa kann die Menschen für sich gewinnen. Sentiment(classification='neg', p_pos=0.47413793103448265, p_neg=0.5258620689655171)
#
#
#
# Danke schön. Sentiment(classification='pos', p_pos=0.5, p_neg=0.5)
#
#
#
# ({ Sentiment(classification='pos', p_pos=0.5, p_neg=0.5)
#
# 10}) Sentiment(classification='pos', p_pos=0.5, p_neg=0.5)
#
#
#
# Sehr geehrter Herr Präsident! Sentiment(classification='pos', p_pos=0.5, p_neg=0.5)
#
# Sehr geehrte Damen und Herren! Sentiment(classification='pos', p_pos=0.5, p_neg=0.5)
#
# Sehr geehrte Frau Ministerin Karliczek, Sie nehmen Milliarden in die Hand, verteilen viel Geld, und trotz allem reißt die Kritik an Ihnen nicht ab. Sentiment(classification='pos', p_pos=0.7003093975248207, p_neg=0.29969060247518026)
#
# Die Linke, die SPD, die Grünen, die FDP und die „heute-show“ – alle gemeinsam gegen Karliczek.
#
# ({0})
#
# Welches Spiel wird hier eigentlich gespielt? Sentiment(classification='neg', p_pos=0.47413793103448326, p_neg=0.5258620689655165)
#
# Wer ist denn, meine Damen und Herren, für die Bildungspolitik in den Ländern verantwortlich?
#
# ({1 Sentiment(classification='neg', p_pos=0.4741379310344821, p_neg=0.5258620689655178)
#
# } Sentiment(classification='pos', p_pos=0.5, p_neg=0.5)
#
# )
#
# In den meisten Bundesländern wird die Bildungspolitik seit Jahren von Rot-Grün verantwortet. Sentiment(classification='pos', p_pos=0.6555834378920953, p_neg=0.3444165621079046)
#
# Wer hat denn erst kürzlich den Rotstift in die Hand genommen und bei Bildung und Forschung angesetzt, obwohl sie im Wahlkampf landauf, landab versprochen haben, mehr für die Bildung zu tun? Sentiment(classification='neg', p_pos=0.4035804939066316, p_neg=0.5964195060933676)
#
# Das waren die SPD und Herr Scholz. Sentiment(classification='pos', p_pos=0.9084084084084074, p_neg=0.09159159159159133)
#
# Wer hat denn, meine Damen und Herren, beim DigitalPakt und beim Pakt für die Hochschulen darauf gedrängt, dass der Bund den Ländern Milliarden auch ohne ausreichende Kontroll- und Steuerungsrechte überweist? Sentiment(classification='neg', p_pos=0.2793742017879951, p_neg=0.7206257982120049)
#
# Der Bundesrechnungshof hat das zu Recht jüngst kritisiert. Sentiment(classification='pos', p_pos=0.8254716981132089, p_neg=0.17452830188679222)
#
# War das Frau Karliczek alleine? Sentiment(classification='pos', p_pos=0.9805030117298951, p_neg=0.019496988270104612)
#
# Nein, das waren Sie alle miteinander. Sentiment(classification='pos', p_pos=0.9166666666666673, p_neg=0.08333333333333334)
#
# Und Sie alle miteinander rufen jetzt: Haltet den Dieb!  Sentiment(classification='pos', p_pos=0.5, p_neg=0.5)
#
# – Das, meine Damen und Herren, ist mir zu billig, das ist der AfD-Fraktion zu billig.
#
# ({2})
#
#  Sentiment(classification='neg', p_pos=0.3500000000000005, p_neg=0.6499999999999997)
#
# Ähnlich ist es beim BAföG. Da beklagen Sie bürokratische Hürden. Sentiment(classification='pos', p_pos=0.5, p_neg=0.5)
#
# Aber als Sie selbst in Regierungsverantwortung waren und die Chance hatten, diese abzubauen, haben Sie es da getan? Sentiment(classification='neg', p_pos=0.47930818734358177, p_neg=0.5206918126564173)
#
# Nein. Sentiment(classification='pos', p_pos=0.5, p_neg=0.5)
#
# Das BAföG ist nach wie vor ein Bürokratiemonster, das potenzielle Antragsteller abschreckt mit dem Ergebnis, dass heute nur jeder fünfte anspruchsberechtigte Student überhaupt einen Antrag stellt. Sentiment(classification='pos', p_pos=0.9820008674280762, p_neg=0.017999132571924256)
#
# Das, meine Damen und Herren, ist ein Armutszeugnis für das BAföG.
#
# ({3})
#
# Wären wir nicht der Bundestag, sondern ein Unternehmen, müssten wir uns dann nicht alle miteinander fragen, warum das Produkt BAföG immer weniger nachgefragt wird? Sentiment(classification='pos', p_pos=0.700000000000001, p_neg=0.2999999999999997)
#
# Wer den Einundzwanzigsten BAföG-Bericht aus dem Jahr 2017 einmal zur Hand nimmt oder sich bei den Studenten umhört, der stellt fest, dass es neben dem schon genannten bürokratischen Aufwand noch einen weiteren wichtigen Grund gibt, warum das BAföG zum Ladenhüter wurde: Sentiment(classification='pos', p_pos=0.6778191642840283, p_neg=0.32218083571597295)
#
# Die neue Studentengeneration will sich nicht verschulden, und sie will möglichst unabhängig sein, gerade auch, was die Finanzierung des Studiums betrifft. Sentiment(classification='pos', p_pos=0.7468249320099566, p_neg=0.2531750679900445)
#
# Ich finde, das ist auch ihr gutes Recht. Sentiment(classification='pos', p_pos=0.9166666666666673, p_neg=0.08333333333333334)
#
# Das Verwaltungsmonster BAföG nimmt darauf auch in der uns heute vorliegenden Form keine Rücksicht. Sentiment(classification='pos', p_pos=0.9150058616647122, p_neg=0.08499413833528718)
#
# Frau Karliczek, an dieser Stelle sind Sie leider zu kurz gespru ngen. Sentiment(classification='pos', p_pos=0.7000000000000001, p_neg=0.3000000000000001)
#
# Wir finden, das BAföG darf eben keine Hürde sein,
#
# ({4})
#
# sondern es muss ein Sprungbrett für einen erfolgreichen akademischen Abschluss des Studiums und eben auch der Berufsausbildung sein. Sentiment(classification='pos', p_pos=0.9545454545454548, p_neg=0.045454545454545484)
#
#
#
# Wir finden auch, dass es durchaus in Ordnung ist, wenn Studenten einem Nebenjob nachgehen. Sentiment(classification='pos', p_pos=0.5, p_neg=0.5)
#
# Nur, der Nebenjob darf eben nicht zum Hauptjob werden. Sentiment(classification='neg', p_pos=0.38888888888888884, p_neg=0.6111111111111108)
#
# Studenten sind Lernende und keine Arbeitnehmer. Sentiment(classification='pos', p_pos=0.5, p_neg=0.5)
#
# An dieser Stelle sage ich: Wehret den Anfängen! Sentiment(classification='pos', p_pos=0.6428571428571421, p_neg=0.35714285714285754)
#
# Liebe FDP, da müssen wir aufpassen. Sentiment(classification='pos', p_pos=0.5, p_neg=0.5)
#
#
#
# Wir sehen das BAföG weiterhin als eine Sozialleistung für all diejenigen, die von ihren Familien nicht ausreichend unterstützt werden können. Sentiment(classification='pos', p_pos=0.9547953570775602, p_neg=0.04520464292243884)
#
#
#
# ({5})
#
# Deshalb hält die AfD-Fraktion an einem eltern- und einkommensunabhängigen BAföG fest. Sentiment(classification='pos', p_pos=0.549522154648132, p_neg=0.4504778453518681)
#
# Wir können und dürfen es uns nicht leisten, mit dem BAföG Kinder aus wohlhabenden Familien zu finanzieren. Sentiment(classification='pos', p_pos=0.7222222222222217, p_neg=0.2777777777777784)
#
#
#
# ({6})
#
# Das, meine Damen und Herren, wäre auch dem Steuerzahler nur schwer vermittelbar. Sentiment(classification='pos', p_pos=0.9166666666666673, p_neg=0.08333333333333344)
#
#
#
# Herr Präsident! Sentiment(classification='pos', p_pos=0.5, p_neg=0.5)
#
# Sehr geehrte Damen und Herren! Sentiment(classification='pos', p_pos=0.5, p_neg=0.5)
#
# Seit heute wissen wir: Das jahrelange Warten hat ein Ende. Sentiment(classification='pos', p_pos=0.9570765661252892, p_neg=0.04292343387470993)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[17], line 8
#       5 for span in doc.sents:
#       6     #doc = nlp(beitrag)
#       7     blob = TextBlob(span.text, analyzer = NaiveBayesAnalyzer())
# ----> 8     print(span, blob.sentiment)
#       9     print (' ')
#
# File ~\anaconda3\Lib\site-packages\textblob\decorators.py:24, in cached_property.__get__(self, obj, cls)
#      22 if obj is None:
#      23     return self
# ---> 24 value = obj.__dict__[self.func.__name__] = self.func(obj)
#      25 return value
#
# File ~\anaconda3\Lib\site-packages\textblob\blob.py:432, in BaseBlob.sentiment(self)
#     423 @cached_property
#     424 def sentiment(self):
#     425     """Return a tuple of form (polarity, subjectivity ) where polarity
#     426     is a float within the range [-1.0, 1.0] and subjectivity is a float
#     427     within the range [0.0, 1.0] where 0.0 is very objective and 1.0 is
#    (...)
#     430     :rtype: namedtuple of the form ``Sentiment(polarity, subjectivity)``
#     431     """
# --> 432     return self.analyzer.analyze(self.raw)
#
# File ~\anaconda3\Lib\site-packages\textblob\en\sentiments.py:88, in NaiveBayesAnalyzer.analyze(self, text)
#      84 """Return the sentiment as a named tuple of the form:
#      85 ``Sentiment(classification, p_pos, p_neg)``
#      86 """
#      87 # Lazily train the classifier
# ---> 88 super(NaiveBayesAnalyzer, self).analyze(text)
#      89 tokens = word_tokenize(text, include_punc=False)
#      90 filtered = (t.lower() for t in tokens if len(t) >= 3)
#
# File ~\anaconda3\Lib\site-packages\textblob\base.py:94, in BaseSentimentAnalyzer.analyze(self, text)
#      92 # Lazily train the classifier
#      93 if not self._trained:
# ---> 94     self.train()
#      95 # Analyze text
#      96 return None
#
# File ~\anaconda3\Lib\site-packages\textblob\decorators.py:35, in requires_nltk_corpus.<locals>.decorated(*args, **kwargs)
#      32 @wraps(func)
#      33 def decorated(*args, **kwargs):
#      34     try:
# ---> 35         return func(*args, **kwargs)
#      36     except LookupError as err:
#      37         print(err)
#
# File ~\anaconda3\Lib\site-packages\textblob\en\sentiments.py:78, in NaiveBayesAnalyzer.train(self)
#      75 pos_ids = nltk.corpus.movie_reviews.fileids('pos')
#      76 neg_feats = [(self.feature_extractor(
#      77     nltk.corpus.movie_reviews.words(fileids=[f])), 'neg') for f in neg_ids]
# ---> 78 pos_feats = [(self.feature_extractor(
#      79     nltk.corpus.movie_reviews.words(fileids=[f])), 'pos') for f in pos_ids]
#      80 train_data = neg_feats + pos_feats
#      81 self._classifier = nltk.classify.NaiveBayesClassifier.train(train_data)
#
# File ~\anaconda3\Lib\site-packages\textblob\en\sentiments.py:79, in <listcomp>(.0)
#      75 pos_ids = nltk.corpus.movie_reviews.fileids('pos')
#      76 neg_feats = [(self.feature_extractor(
#      77     nltk.corpus.movie_reviews.words(fileids=[f])), 'neg') for f in neg_ids]
#      78 pos_feats = [(self.feature_extractor(
# ---> 79     nltk.corpus.movie_reviews.words(fileids=[f])), 'pos') for f in pos_ids]
#      80 train_data = neg_feats + pos_feats
#      81 self._classifier = nltk.classify.NaiveBayesClassifier.train(train_data)
#
# File ~\anaconda3\Lib\site-packages\nltk\corpus\reader\api.py:406, in CategorizedCorpusReader.words(self, fileids, categories)
#     405 def words(self, fileids=None, categories=None):
# --> 406     return super().words(self._resolve(fileids, categories))
#
# File ~\anaconda3\Lib\site-packages\nltk\corpus\reader\plaintext.py:76, in PlaintextCorpusReader.words(self, fileids)
#      67 def words(self, fileids=None):
#      68     """
#      69     :return: the given file(s) as a list of words
#      70         and punctuation symbols.
#      71     :rtype: list(str)
#      72     """
#      73     return concat(
#      74         [
#      75             self.CorpusView(path, self._read_word_block, encoding=enc)
# ---> 76             for (path, enc, fileid) in self.abspaths(fileids, True, True)
#      77         ]
#      78     )
#
# File ~\anaconda3\Lib\site-packages\nltk\corpus\reader\api.py:195, in CorpusReader.abspaths(self, fileids, include_encoding, include_fileid)
#     192 elif isinstance(fileids, str):
#     193     fileids = [fileids]
# --> 195 paths = [self._root.join(f) for f in fileids]
#     197 if include_encoding and include_fileid:
#     198     return list(zip(paths, [self.encoding(f) for f in fileids], fileids))
#
# File ~\anaconda3\Lib\site-packages\nltk\corpus\reader\api.py:195, in <listcomp>(.0)
#     192 elif isinstance(fileids, str):
#     193     fileids = [fileids]
# --> 195 paths = [self._root.join(f) for f in fileids]
#     197 if include_encoding and include_fileid:
#     198     return list(zip(paths, [self.encoding(f) for f in fileids], fileids))
#
# File ~\anaconda3\Lib\site-packages\nltk\data.py:334, in FileSystemPathPointer.join(self, fileid)
#     332 def join(self, fileid):
#     333     _path = os.path.join(self._path, fileid)
# --> 334     return FileSystemPathPointer(_path)
#
# File ~\anaconda3\Lib\site-packages\nltk\compat.py:41, in py3_data.<locals>._decorator(*args, **kwargs)
#      39 def _decorator(*args, **kwargs):
#      40     args = (args[0], add_py3_data(args[1])) + args[2:]
# ---> 41     return init_func(*args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\nltk\data.py:311, in FileSystemPathPointer.__init__(self, _path)
#     304 """
#     305 Create a new path pointer for the given absolute path.
#     306
#     307 :raise IOError: If the given path does not exist.
#     308 """
#     310 _path = os.path.abspath(_path)
# --> 311 if not os.path.exists(_path):
#     312     raise OSError("No such file or directory: %r" % _path)
#     313 self._path = _path
#
# File <frozen genericpath>:19, in exists(path)
#
# KeyboardInterrupt:

# %%
doc._.polarity
# Out:
# -0.2

# %%
doc._.subjectivity
# Out:
# 0.6

# %%
doc._.assessments
# Out:
# [(['stark'], -0.2, 0.6, None)]

# %%
for beitrag in beitraege:
    doc = nlp(beitrag)
    for span in doc.sents:
        print(span.text, span._.polarity)
# Out:
#  0.0
# Sehr geehrter Herr Präsident! Liebe Kolleginnen und Kollegen! 0.0
# Unser Grundgesetz ist ein Segen der deutschen Geschichte, mehr als die Summe seiner Artikel, mehr als ein historisches Dokument. 0.0
# Das Grundgesetz hat die Menschen in Deutschland für sich gewonnen.
#
#  0.0
# ({0})
#
# Meine Damen und Herren, das Grundgesetz ist heute eine lebendige Verfassung für über 80 Millionen Menschen in unserem Land, und es hat die Menschen im Laufe der Geschichte zweimal für sich gewonnen.
#
#  0.0
# Unser Grundgesetz ist entstanden nach nationalsozialistischer Diktatur, nach Krieg und Zerstörung. 0.0
# Deutschland war damals seiner geistigen Grundlage beraubt, moralisch gescheitert und entkernt. 0.0
# Und es waren einige wenige Entscheidungsträger im Parlamentarischen Rat, die in dieser Stunde mit dem Grundgesetz eine neue Werteordnung geschaffen haben und damit der Bundesrepublik einen ethisch-moralischen, wirtschaftlichen und gesellschaftlichen Neuanfang ermöglicht haben. 0.0
# Was damals einer kleinen Gruppe gelungen ist, wurde dann zu einer gemeinsamen, einer geteilten Überzeugung der Menschen in unserem Land. 0.0
# Aus einem Projekt der wenigen wurde eine Werteordnung für Millionen. 0.0
# Das ist ein Grund, warum wir heute feiern.
#
#  0.0
# Aber das Grundgesetz hat auch ein zweites Mal die Menschen für sich gewonnen: vor 30 Jahren, als die Menschen in der DDR bei den Montagsdemonstrationen auf die Straßen gingen. 0.0
# Denn diese Demonstrationen waren im Kern ja auch ein Ruf nach dem Grundgesetz, nach seinen Werten und seiner freiheitlich-demokratischen Grundordnung. 0.0
# In all den Jahren des Unrechts der DDR war es immer auch der dringende Appell der Präambel, „die Einheit und Freiheit Deutschlands zu vollenden“, die den Menschen im Osten Hoffnung gegeben hat, meine Damen und Herren.
#
#  0.0
# ({1})
#
#  0.0
# Wenn wir heute 70 Jahre Grundgesetz feiern, dann feiern wir auch, dass Demokratie, Meinungsfreiheit und Menschenwürde stärker sind als Diktatur, als Stacheldraht, als Schießbefehl. 0.0
# Dieses Grundgesetz hat Mauern eingerissen und Menschen zusammengeführt. 0.0
# Heute ist unser Grundgesetz die gemeinsame Klammer, eine Klammer der Freiheit, der Gleichheit, der Brüderlichkeit, eine Klammer für Einigkeit, für Recht und Freiheit. 0.0
# Diese Klammer ist nicht nur so stark, weil sie uns als Bürger schützt, sondern vor allem, weil Bürger unsere Verfassung schützen. -0.2
# Das kann man zu Recht auch Patriotismus nennen.
#
#  0.0
# ({2})
#
#  0.0
# Mit dieser Klammer bildet das Grundgesetz übrigens auch die Voraussetzung für gelungene Integration. 0.0
# Wer integrieren will, der muss auch wissen, wohin – und wir wissen, wohin: in die Werteordnung unseres Grundgesetzes und seiner Grundsätze für das Zusammenleben in Deutschland. 0.0
# Dieses Grundgesetz grenzt niemanden aus. 0.0
# Es ist ein Grundgesetz für alle Menschen, egal welchen Glaubens, welcher Herkunft, welcher Kultur, welcher Tradition.
#
#  0.0
# ({3})
#
# Dieses Grundgesetz garantiert allen Menschen in Deutschland Rechte und Privilegien, aber es fordert auch etwas ein. 0.0
# Genau diese Erwartung einzulösen, ist der Ausgangspunkt für eine gelungene Integration.
#
#  0.0
# ({4})
#
#  0.0
# Der Parlamentarische Rat hat als Grundlage des Wertefundaments unseres Grundgesetzes eine christliche Prägung verankert. 0.0
# In „Verantwortung vor Gott und den Menschen“ – so laute n die ersten Worte unserer Verfassung. 0.0
# Genau das ist der Ausgangspunkt für vieles, was folgt: Die Würde des Menschen, die Freiheit und Gleichheit, das Asylrecht, die Subsidiarität, der Schutz des Eigentums – diese Werte gründen auf der christlichen Soziallehre. 0.0
# Deswegen will ich an dieser Stelle auch denen in Erinnerung rufen, die in einer Leitkulturdebatte gerne meinen, dass eine spezifische deutsche Kultur nicht identifizierbar sei und deswegen das Grundgesetz der alleinige Maßstab sei: Ja, das Grundgesetz ist der Maßstab. 0.0
# Aber das ist kein Argument gegen eine Leitkultur, es ist gerade die Bestätigung unserer christlichen Werteordnung, meine Damen und Herren.
#
#  0.0
# ({5})
#
#  0.0
# Eine zentrale Garantie des Grundgesetzes, das sich übrigens unmittelbar auf unser tägliches Miteinander auswirkt, ist die Meinungsfreiheit. 0.0
# Sie ist der klare Ausgangspunkt einer offenen, positiven politischen Debattenkultur, aber übrigens auch eine tägliche Verpflichtung für uns alle, Meinungsfreiheit nicht auf die eigene Meinung zu verengen, Meinung nicht aus der Debatte auszugrenzen, sondern sie in die Mitte der Debatte zu holen, sie zuzulassen, zuzuhören, sich Diskussionen zu stellen und zu versuchen, mit Argumenten zu überzeugen, nicht mit Lautstärke.
#
#  0.0
# ({6})
#
# Aber auch das sage ich klar und deutlich: 0.0
# Die in unserem Grundgesetz verankerte Meinungsfreiheit kennt auch Grenzen. 0.0
# Und die Grenzen verlaufen nicht dort, wo die eigene Meinung endet, sondern dort, wo die Meinungsfreiheit missbraucht wird, um die verfassungsrechtliche Ordnung anzugreifen oder zu zerstören oder den Parlamentarismus zu untergraben.
#
#  0.0
# Liebe Kolleginnen und Kollegen, wer die Religionsfreiheit abschaffen will und wer den Nationalsozialismus relativiert, der kann sich hier nicht hinstellen und sagen, er sei ein Freund des Grundgesetzes. 0.0
# Er ist das Gegenteil.
#
#  0.0
# ({7})
#
#  0.0
# Wer immer wieder Wege zum Kommunismus sucht und wer das Unrecht der DDR verharmlost, der kann sich hier nicht hinstellen und sagen, er sei ein Freund des Grundgesetzes. 0.0
# Er ist das Gegenteil, liebe Freunde.
#
#  0.0
# ({8})
#
# Das Grundgesetz – das ist ein bedeutender Aspekt – ist eine zutiefst föderale Verfassung. 0.0
# Dafür formuliert das Grundgesetz sogar eine Ewigkeitsgarantie. 0.0
# Heute wissen wir: Der Föderalismus ist ein absolutes Erfolgsmodell. 0.0
# Er ist zwar nicht jeden Tag immer gleich einfach zu erfüllen, aber dass politische Entscheidungen nicht nur in Berlin, sondern auch in den Landeshauptstädten getroffen werden, das stärkt unsere Demokratie, meine Damen und Herren, und schwächt sie nicht.
# Das, meine Damen und Herren, ist ein Armutszeugnis für das BAföG.
#
# ({3})
#
# Wären wir nicht der Bundestag, sondern ein Unternehmen, müssten wir uns dann nicht alle miteinander fragen, warum das Produkt BAföG immer weniger nachgefragt wird? 0.0
# Wer den Einundzwanzigsten BAföG-Bericht aus dem Jahr 2017 einmal zur Hand nimmt oder sich bei den Studenten umhört, der stellt fest, dass es neben dem schon genannten bürokratischen Aufwand noch einen weiteren wichtigen Grund gibt, warum das BAföG zum Ladenhüter wurde: 0.0
# Die neue Studentengeneration will sich nicht verschulden, und sie will möglichst unabhängig sein, gerade auch, was die Finanzierung des Studiums betrifft. 0.0
# Ich finde, das ist auch ihr gutes Recht. 0.0
# Das Verwaltungsmonster BAföG nimmt darauf auch in der uns heute vorliegenden Form keine Rücksicht. 0.0
# Frau Karliczek, an dieser Stelle sind Sie leider zu kurz gespru ngen. 0.0
# Wir finden, das BAföG darf eben keine Hürde sein,
#
# ({4})
#
# sondern es muss ein Sprungbrett für einen erfolgreichen akademischen Abschluss des Studiums und eben auch der Berufsausbildung sein.
#
#  0.0
# Wir finden auch, dass es durchaus in Ordnung ist, wenn Studenten einem Nebenjob nachgehen. 0.0
# Nur, der Nebenjob darf eben nicht zum Hauptjob werden. 0.0
# Studenten sind Lernende und keine Arbeitnehmer. 0.0
# An dieser Stelle sage ich: Wehret den Anfängen! 0.0
# Liebe FDP, da müssen wir aufpassen.
#
#  0.0
# Wir sehen das BAföG weiterhin als eine Sozialleistung für all diejenigen, die von ihren Familien nicht ausreichend unterstützt werden können.
#
#  0.0
# ({5})
#
#  0.0
# Deshalb hält die AfD-Fraktion an einem eltern- und einkommensunabhängigen BAföG fest. 0.0
# Wir können und dürfen es uns nicht leisten, mit dem BAföG Kinder aus wohlhabenden Familien zu finanzieren.
#
#  0.0
# ({6})
#
# Das, meine Damen und Herren, wäre auch dem Steuerzahler nur schwer vermittelbar. 0.0
#
#
# Herr Präsident! 0.0
# Sehr geehrte Damen und Herren! 0.0
# Seit heute wissen wir: 0.0
# Das jahrelange Warten hat ein Ende. 0.0
# Ministerin Karliczek hat ihre Unterschrift unter den Digitalpakt gesetzt. 0.0
# Es kann endlich losgehen, und das ist gut.
#
#  0.0
# Im März haben wir mit sehr breiter Mehrheit in diesem Hause das Grundgesetz geändert. 0.0
# Ich freue mich, dass Sie den Vorschlag von FDP und Grünen aufgenommen haben und der Bund künftig nicht nur in Kabel und Beton investieren darf, sondern auch in Personal und Inhalte. 0.0
# Diese Chance wollen und müssen wir nutzen.
#
#  0.0
# ({0})
#
# Deshalb dürfen wir jetzt nicht bei diesem Digitalpakt stehen bleiben, sondern wir müssen den nächsten Schritt gehen. 0.0
# Ich nenne Ihnen fünf Punkte, warum wir einen Digitalpakt 2.0 brauchen:
#
# Erstens. 0.0
# Die technische Ausstattung muss nicht nur da sein, sondern muss auch fachmännisch instand gehalten werden. 0.0
# Die Lehrkräfte haben als Pioniere eine super Arbeit geleistet. 0.3333333333333333
# Wir brauchen jetzt aber IT-Spezialisten; 0.0
# denn Lehrer müssen sich wieder ganz aufs Unterrichten konzentrieren. 0.0
# Im Klassenzimmer, bei unseren Kindern, da brauchen wir ihre ganze Aufmerksamkeit.
#
# ({1})
#
# Zwei tens. 0.0
# Wir müssen die Lehrkräfte besser darauf vorbereiten, im digitalen Zeitalter zu unterrichten. 0.0
# Der Bund hätte hier längst mehr machen können. 0.0
# Seit 2015 gibt es die Qualitätsoffensive Lehrerbildung, aber nur 2 von 59 Hochschulen haben den Schwerpunkt „digitale Bildung“ für die Lehrerausbildung gewählt. 0.0
# Da läuft etwas schief. 0.0
# Wer heute als Lehrer nicht mit digitalen Medien umgehen kann, der wird morgen nicht vor einer Klasse bestehen können. 0.0
# Das ist verantwortungslos. 0.0
# Da hätten Sie, Frau Ministerin Karliczek, viel früher nachsteuern müssen.
#
#  0.0
# ({2})
#
# – Die ist nicht da.
#
#  0.0
# Drittens. 0.0
# Ties Rabe, SPD-Schulsenator in meiner Heimatstadt Hamburg, rühmt sich damit, dass er mit den Mitteln aus dem Digitalpakt 45 000 Computer für die Schulen anschaffen will. 0.0
# Gleichzeitig sagt er: Es sind nur zwei Lernprogramme vorhanden.  0.0
# – Für alle Unterrichtsfächer, Jahrgänge und Schulformen zusammen, wohlgemerkt. 0.0
# Nur zwei Lernprogramme! 0.0
# Das ist ein Witz. 0.0
# Das kann gar nicht funktionieren. 0.0
# Die Schulen brauchen eigene Budgets und mehr Freiheit, um digitale Schulbücher anzuschaffen. 0.0
# Die Politik muss hier runter von der Bremse.
#
# ({3})
#
# Viertens. 0.0
# Wir brauchen klare Standards für den Schutz sensibler Schüler- und Lerndaten. 0.0
# Will ein Lehrer eine Lernsoftware einsetzen, dann muss ein Schulleiter eine 120-seitige Datenschutzerklärung unterzeichnen – ohne rechtlichen Beistand. 0.0
# Sucht der Schulleiter Hilfe bei der Kommune, dann verweist die ihn ans Land, und das Land verweist wiederum an die Kommune. 0.0
# Ein Lehrer, der die Lernsoftware dann dennoch einsetzt, der steht mit einem Bein im Gefängnis. 0.0
# Das ist ein einziger Albtraum. 0.0
# Die Verantwortung dafür tragen wir als Gesetzgeber. 0.0
# Wir müssen endlich Klarheit schaffen beim Datenschutz.
#
#  0.0
# ({4})
#
# Fünftens. 0.0
# Die Nutzungsdaten aus Lernprogrammen ermöglichen eine Revolution in der Bildungsforschung. 0.0
# Zum Vergleich: Die PISA-Studien beruhen auf Stichproben von etwa 5 000 Schülern in Deutschland, die alle drei Jahre erhoben werden. 0.0
# Künftig stehen Lerndaten von über 10 Millionen Schülern zur Verfügung – für jeden Jahrgang, jedes Fach, jeden Tag. 0.0
# Daran lässt sich dann glasklar ablesen, wie Lerninhalte am erfolgreichsten vermittelt werden – als Text, Audio oder Bild. 0.0
# Diesen großen Wissensschatz nicht zu nutzen, das wäre grob fahrlässig. 0.0
# Doch auch dafür braucht es klare Vorgaben zum Schutz sensibler Daten.
#
#  0.0
# ({5})
#
# Meine Damen und Herren, der vorliegende Digitalpakt kümmert sich nur um die technische Infrastruktur; 0.0
# aber das reicht nicht. 0.0
# Wir brauchen einen Digitalpakt 2.0; 0.0
# sonst wird technische Infrastruktur im Wert von über 5 Milliarden Euro veraltet sein, bevor sie überhaupt eingesetzt werden kann. 0.0
# Das müssen wir unbedingt verhindern. 0.0
# Frau Karliczek, beginnen Sie jetzt mit den Verhandlungen.
#
#  0.0
# Vielen Dank.
#
#  0.0
# ({6}) 0.0
#
#
# Herr Präsident! Liebe Kolleginnen und Kollegen! 0.0
# Ich freue mich, dass wir heute erneut über den DigitalPakt Schule diskutieren, und heute nicht mehr als Vorhaben, sondern als beschlossenes Projekt. 0.0
# Die Länder haben die Verwaltungsvereinbarung unterzeichnet. 0.0
# Es ist begonnen worden, die Förderkriterien entsprechend auszuarbeiten, und die ersten Gelder können noch in diesem Jahr fließen.
#
#  0.0
# ({0})
#
#  0.0
# Die Schulen freuen sich auf die Mittel des Bundes. 0.0
# Und nach langer Vorarbeit sollten wir uns vielleicht auch mal zumindest einen Moment lang freuen, dass es uns gelungen ist, dieses vom Umfang her ja nicht gerade kleine und von der Architektur her auch nicht gerade einfache Projekt auf den Weg zu bringen.
#
#  0.0
# Und was macht die FDP? 0.0
# In Ihrem Antrag reden Sie den gerade erst beschlossenen Digitalpakt schlecht. 0.0
# Noch bevor der erste Euro der 5 Milliarden überhaupt geflossen ist, bevor die erste Evaluierung stattgefunden hat, fordern Sie einen Digitalpakt 2.0. 0.0
# Das ist gerade so, als ob man plant, den Vorgarten zu bepflanzen, obwohl einem das Grundstück noch gar nicht gehört.
#
#  0.0
# ({1})
#
#  0.0
# Das zeigt sich schon im er sten Satz Ihres Antrags. 0.0
# Sie schreiben:
#
# Nachdem die Schulen jahrelang auf den angekündigten Digitalpakt warten mussten, haben Bund und Länder ihn nun unterzeichnet.
#
#  0.0
# Ja, es hat leider etwas länger gedauert, als wir sicherlich wollten.
#
#  0.0
# ({2})
#
#  0.0
# Aber zur Wahrheit gehört eben dazu, liebe Kolleginnen und Kollegen der FDP und auch der Grünen, dass die ständig neuen Forderungen mit Blick auf die Zustimmung zur Grundgesetzänderung nicht gerade ein Beschleuniger im Prozess gewesen sind.
#
#  0.0
# ({3})
#
#  0.0
# Ohne Ihre Blockadepolitik wären wir hier auch deutlich schneller vorangekommen.
#
#  0.0
# ({4})
#
# Ähnliches gilt für die Grünen. 0.0
# Mit Blick auf widersprüchliche Haltungen kann man analysieren, dass es ihnen auf der einen Seite im Bund gar nicht weit genug gehen konnte hinsichtlich Einmischung in die Schulpolitik. 0.0
# Von Länderseite hingegen kam der schärfste Widerstand, kam die größte Kritik woher? 0.0
# Genau, aus Baden-Württemberg, namentlich vom Ministerpräsidenten Winfried Kretschmann, der von einem Frontalangriff auf die föderale Ordnung sprach.
#
#  0.0
# Als Union haben wir uns von Anfang an, vor allem auch mit Blick auf ein gesamtstaatliches Interesse, das Ziel gesetzt, die Länder hier zu unterstützen, einen Anschub zu leisten mit Blick auf die Digitalisierung der Schulen. 0.0
# Aber auch nach der Grundgesetzänderung ist für uns klar, dass die Hoheit der Länder bei der Verantwortung im Bildungswesen nach wie vor besteht.
#
#  0.0
# ({5})
#
#  0.0
# Wenn ich dann Ihren Antrag lese, in dem steht, dass wir weit umfangreicher unterstützen könnten, dann ist schon klar, worauf Sie eigentlich hinauswollen: 0.0
# Sie wollen ein Rundum-sorglos-Paket vonseiten des Bundes zugunsten der Länder. 0.0
# Wir meinen aber, dass der Digitalpakt zielgerichtet unterstützt, aber eben nicht sämtliche Aufgaben, die die Länder nach wie vor erfüllen müssen, übernehmen kann.
#
# ({6})
#
# Entscheidend war deswegen für uns das Kriterium der Zusätzlichkeit. 0.0
# Es bringt eben nichts, wenn der Bund seine Ausgaben auf der einen Seite erhöht und die Länder auf der anderen Seite ihre Ausgaben entsprechend zurückfahren.
#
#  0.0
# ({7})
#
# Dann haben wir ein Nullsummenspiel. 0.0
# Das hilft weder den Lehrkräften noch den Schülerinnen und Schülern.
#
#  0.0
# ({8})
#
# Und dann zieht sich durch Ihren Antrag ein breiter Katalog von Forderungen nach Maßnahmen, die zum größten Teil aber eigentlich schon beschlossen sind. 0.0
# Ich nenne Ihnen drei Beispiele.
#
#  0.0
# Zum Ersten. 0.0
# Sie fordern Anschubfinanzierung für den Einsatz von IT-Administratoren. 0.0
# Dafür brauchen wir keinen Digitalpakt 2.0. 0.0
# Wenn Sie vielleicht mal in die Verwaltungsvereinbarung genau reinschauen und auf Seite 4 lesen, dann stellen Sie fest – dort ist es entsprechend beschrieben –, dass Planung, Beschaffung, Aufbau und Inbetriebnahme von Administration sowie Wartung förderfähig sind.
#
#  0.0
# ({9})
#
#  0.0
# Zum Zweiten bemängeln Sie, dass digitale Kompetenzen mit Blick auf die Lehreraus- und -fortbildung bisher nur Randthemen wären und dass diese Kompetenzen auch im Rahmen der Qualitätsoffensive Lehrerbildung entsprechend ausgebaut werden sollten. 0.0
# Das ist zunächst einmal gar nicht falsch. 0.0
# Aber auch mit dieser Forderung bleiben Sie hinter dem zurück, was bisher Beschlusslage ist. 0.0
# So hat bereits mit der zweiten Förderphase der Qualitätsoffensive Lehrerbildung eine klare Schwerpunktbildung stattgefunden. 0.0
# Mit Blick auf die Digitalisierung in der Lehrerbildung ist hier für die Jahre 2020 bis 2023 eine entscheidende Basis gelegt worden.
#
#  0.0
# ({10})
#
# Übrigens: Die Förderbekanntmachung wurde im November letzten Jahres veröffentlicht; 0.0
# das nur ein kleiner Servicehinweis an die selbsternannte Serviceopposition.
#
#  0.0
# Zum Dritten kritisieren Sie, dass die Nutzung digitaler Hilfsmittel im Unterricht schwerfalle, weil noch keine Medienkonzepte da wären. 0.0
# Aber auch da braucht es keinen Digitalpakt 2.0. 0.0
# Denn beim DigitalPakt Schule ist der klare Grundsatz: Keine Ausstattung ohne entsprechendes Konzept. 0.0
# Dieser Grundsatz war gerade für uns als Union wichtig, weil wir natürlich keine Infrastruktur fördern wollen, die nachher nicht genutzt werden kann.
#
#  0.0
# Übrigens, Kollegin Suding: Natürlich ist ein zentraler Bestandteil des Digitalpakts, dass die Länder zunächst für die Implementierung der Inhalte in die Curricula und auch für die Lehrerfort- und -ausbildung sorgen. 0.0
# Deswegen stimmt es eben nicht, dass sich der Digitalpakt nur um die Frage der Infrastruktur kümmern würde, sondern die Länder leisten hier den entsprechenden Beitrag.
#
#  0.0
# Wenn man noch einmal in die Verwaltungsvereinbarung schaut, gilt auch da ganz klar: Wer Mittel beantragen will, der muss ein pädagogisches Konzept vorlegen.  0.0
# – Also auch hier fordern Sie Dinge, die längst Bestandteil der Beschlusslage sind.
#
#  0.0
# ({11})
#
#  0.0
# Ich kann Ihnen abschließend nur empfehlen, dass Sie sich selbst vielleicht noch einmal die Verwaltungsvereinbarung und insgesamt den DigitalPakt Schule erschließen und zu Herzen nehmen. 0.0
# Bevor Sie weiter solche Anträge stellen, wäre das vielleicht der richtige Schritt.
#
#  0.0
# Zu den Anträgen der Grünen und der Linken kann man sicherlich vieles sagen. 0.0
# Ich möchte es so zusammenfassen: 0.0
# Die Grünen wollen wie eh und je, dass sich der Bund im Bereich Bildung weiter einmischt und vor allem entsprechende Gelder zur Verfügung stellt.
#
#  0.0
# ({12})
#
#  0.0
# Deren Bereitstellung ist aber ganz klar Aufgabe der Länder, die im Übrigen momentan Rekordsteuereinnahmen verzeichnen.
#
#  0.0
# Bei den Linken ist die größte Sorge, dass der Digitalpakt – 0.0
#
#
#  0.0
# Frau Präsidentin! 0.0
# Liebe Kolleginnen und Kollegen! 0.0
# Liebe Zuhörerinnen und Zuhörer auf den Tribünen! 0.0
# In Deutschland g ibt es viele stille Heldinnen und Helden, die sich abseits der Öffentlichkeit ehrenamtlich oder nur gegen eine geringe Entschädigung für ihre Mitbürgerinnen und Mitbürger engagieren. 0.0
# Und ganz sicher gehören in Deutschland die Betreuerinnen und Betreuer zu dieser Gruppe, also Menschen, die anderen Menschen helfen, weil diese nicht mehr für sich selber sorgen können. 0.0
# Und für genau diese Gruppe wollen wir mit diesem Gesetz Verbesserungen schaffen. 0.0
# Diese Betreuerinnen und Betreuer müssen wir stärken. 0.0
# Deswegen lassen Sie uns heute den Schritt zu einer höheren Vergütung für die Betreuer und Betreuungsvereine gehen, liebe Kolleginnen und Kollegen.
#
# ({0})
#
# Es gibt in Deutschland über 1,2 Millionen betreute Menschen, um die sich 700 000 ehrenamtliche Betreuer und 12 000 Berufsbetreuer kümmern. 0.0
# In den etwa 830 Betreuungsvereinen werden ehrenamtliche Betreuer ausgebildet. 0.0
# Dieses wertvolle Betreuungssystem sollten wir erhalten. 0.0
# Der Weg dazu sind höhere Vergütungen für die Betreuerinnen und Betreuer.
#
#  0.0
# ({1})
#
#  0.0
# Die Lage hat sich in den letzten Jahren zugespitzt. 0.0
# Es fehlen Betreuer. 0.0
# Die ersten Betreuungsvereine mussten sich auflösen oder stehen kurz davor, weil die heute noch zu niedrige Betreuervergütung die Kosten nicht mehr deckt. 0.0
# Genau das müssen wir ändern. 0.0
# Wenn seit 13 Jahren – vor 13 Jahren war die letzte Erhöhung – die ohnehin schon nicht hohe Vergütung der Betreuer gleich geblieben ist, dann ist es überfällig, dass wir hier etwas tun, liebe Kolleginnen und Kollegen.
#
#  0.0
# ({2})
#
# Wir als Bundesgesetzgeber werden heute unser Soll für die Vergütungserhöhung leisten, indem wir das parlamentarische Verfahren abschließen. 0.0
# In der letzten Wahlperiode ist die Erhöhung der Betreuungsvergütung leider noch an den Ländern gescheitert. 0.0
# Aber, ehrlich gesagt, so hoch ist diese Erhöhung gar nicht. 0.0
# So erhält zum Beispiel ein Vormund ohne besondere Kenntnisse statt bisher 19,50 Euro pro Stunde jetzt 23 Euro pro Stunde. 0.0
# Da kann man sich die Frage stellen, ob wir nicht noch einen Schritt hätten weiter gehen müssen.
#
#  0.0
# ({3})
#
#  0.0
# Viele Sachverständige haben in der Anhörung gesagt, das sei nur ein erster Schritt. 0.0
# Da stimmen wir zu. 0.0
# Es ist ein wichtiger Schritt, aber wir wollen auf lange Sicht eine noch bessere, noch höhere Vergütung.
#
#  0.0
# ({4})
#
#  0.0
# Eine grundlegende Änderung gibt es für Betreuer, bei denen wir Fallpauschalen einführen. 0.0
# Das ist bei der Systematik die aus meiner Sicht wichtigste Neuerung. 0.0
# Damit kann die Vergütung dann individuell nach der jeweiligen Fallkonstellation berechnet werden.
#
#  0.0
# Insgesamt erhöhen wir die Betreuervergütung um immerhin 17 Prozent. 0.0
# Das ist dringend notwendig und auch sinnvoll; 0.0
# denn wir wollen, dass die Menschen, die nicht mehr geschäftsfähig sind, die sich nicht mehr um ihre eigenen Angelegenheiten kümmern können, in Würde betreut werden. 0.0
# Dann muss sich ein Betreuer oder eine Betreuerin eben ausreichend Zeit für eine Tasse Kaffee, für soziale Zuwendungen oder für ein längeres Gespräch nehmen können. 0.0
# Er oder sie soll eben nicht darauf angewiesen sein, schnell die Alltagsgeschäfte abzuhaken und schnell zum nächsten Termin zu eilen, um auch dafür eine Vergütung zu bekommen. 0.0
# Wir glauben also, dass wir mit dieser Vergütungserhöhung auch die Qualität der Betreuung verbessern, indem die Betreuerinnen und Betreuer mehr Zeit für ihre wichtige Aufgabe bekommen.
#
# ({5})
#
# Der vorliegende Gesetzentwurf wurde vom Bundesjustizministerium in enger Zusammenarbeit mit den Ländern erarbeitet. 0.0
# Ein herzliches Dankeschön für diese Tätigkeit an das Ministerium und auch an Katarina Barley, die sich in dieser Frage sehr engagiert hat! 0.0
# Dafür wollen wir ausdrücklich danken.  0.0
# – In den Gesprächen mit den Ländern waren die finanziellen Auswirkungen, die von den Ländern in der letzten Wahlperiode noch als zu hoch eingeschätzt wurden, natürlich Thema. 0.0
# Insofern waren wir ein bisschen über die doch deutliche Kritik der Länder in ihrer Stellungnahme überrascht. 0.0
# Ein gutes Zeichen ist es allerdings, dass der Bundesrat jetzt bald dem Gesetz zustimmen will und es keine Anzeichen für eine Anrufung des Vermittlungsausschusses gibt. 0.0
# Es wäre gut, wenn der Bundesrat dem Gesetz noch vor der Sommerpause zustimmen würde, damit die dringend notwendige Erhöhung kommen kann.
#
#  0.0
# ({6})
#
# Meine Damen und Herren, dieses Gesetz stellt einen guten Kompromiss dar, der die finanziellen Interessen der Länder berücksichtigt und der vor allem den betroffenen Betreuerinnen und Betreuern und auch den Betreuungsvereinen eine ganz große finanzielle Unterstützung zukommen lässt und damit die Zukunft der Betreuung in Deutschland sichert.
#
#  0.0
# Herzlichen Dank.
#
#  0.0
# ({7}) 0.0
#
#
#  0.0
# Guten Abend, Frau Präsidentin! 0.0
# Liebe Kolleginnen und Kollegen! 0.0
# Europa wird aus Mut gemacht. 0.0
# Mut haben Deutschland und Frankreich in den vergangenen Jahrzehnten oft bewiesen, so auch vor 56 Jahren, als sie den Élysée-Vertrag auf den Weg brachten. 0.0
# Nur wenige Jahre nach einem verheerenden Krieg, nach Holocaust, nach Faschismus haben vor allem unsere französischen Freundinnen und Freunde Mut bewiesen, als sie uns die Hand zur Versöhnung gereicht haben.
#
#  0.0
# ({0})
#
# Das war, ist und bleibt beispielgebend für ganz Europa. 0.0
# Versöhnung und Frieden und Verständigung sind möglich.
#
#  0.0
# Jetzt gehen wir einen neuen Weg, nicht, indem wir die alten Pfade verlassen, sondern indem wir mit neuem Mut voranschreiten, gerade in einer Zeit, wo viele an Europa zweifeln, verzweifeln, Ängste vorhanden sind gegenüber Europa, vor der Globalisierung. 0.0
# Das, was wir jetzt mit Ihrer Unterstützung, liebe Kolleginnen und Kollegen, auf den Weg bringen, ist der Versuch, den Menschen deutlich zu machen, dass der Abbau von Grenzen und Mauern und Zäunen, dass mehr Integration, mehr Freundschaft, mehr Zusammenarbeit am Ende einen konkreten Mehrwert für die Bürgerinnen und Bürger in ihrem Alltag versprechen. 0.0
# Deshalb ist die Umsetzung dieses Vertrages aller Ehren und aller Mühen wert.
#
#  0.0
# ({1})
#
#  0.0
# Aber es geht eben nicht nur um eine noch engere deutsch-französische Zusammenarbeit. 0.0
# Es geht auch darum, dass wir Mut machen für mehr Europa. 0.0
# Ich weiß, dass es auch kritische Fragen gibt. 0.0
# Ist das die neue deutsch-französische Dominanz? 0.0
# Wollt ihr uns sagen, wo es langzugehen hat? 0.0
# Mitnichten. 0.0
# Das, was wir in diesem erneuerten Vertrag jetzt angelegt haben, ist ein Angebot an alle Mitgliedstaaten in Nord und Süd, Ost und West, an die kleinen und die großen. 0.0
# Wir brauchen alle, und wir laden alle dazu ein, an einem stärkeren, solidarischeren, handlungsfähigeren Europa mitzuarbeiten. 0.0
# Dieses Angebot steht.
#
#  0.0
# Ich will nur einige wenige Bereiche benennen, wo es notwendig ist, dass wir noch enger zusammenarbeiten, dass wir Vorurteile und Klischees überwinden und dass wir uns gemeinsam an die Arbeit machen. 0.0
# Klimaschutz ist ein wichtiges Thema. 0.0
# In der vergangenen Woche hat es dazu auch eine kritische Diskussion, nicht zuletzt zwischen Deutschland und Frankreich, gegeben. 0.0
# Am Ende hängt es aber maßgeblich von uns Europäerinnen und Europäern ab. 0.0
# Schaffen wir es, Mut zu machen und zu zeigen, dass der Satz von Donald Trump, dass Klimaschutz ein Jobkiller ist, nicht stimmt?
#
#  0.0
# ({2})
#
# Deshalb müssen wir einerseits das Angebot der jungen Leute ernst nehmen, uns kritisch zu unterstützen, aber eben auch die Arbeitnehmerinnen und Arbeitnehmer, die sich Sorgen um ihre Arbeitsplätze machen, mitnehmen. 0.0
# Das können Deutschland und Frankreich in enger Zusammenarbeit mit anderen. 0.0
# Das gilt auch für das soziale Europa.
#
#  0.0
# Im Aachener Vertrag haben wir ein klares Bekenntnis dazu abgegeben, dass Europa sozialer werden muss, dass wir unsere Bürgerinnen und Bürger schützen müssen. 0.0
# Es liegt eine Reihe von Vorschlägen auf dem Tisch: Mindestlöhne überall, soziale Grundsicherung überall, endlich eine gerecht e und faire Besteuerung der international und europaweit agierenden Konzerne.
#
#  0.0
# ({3})
#
#  0.0
# Das geht nur, wenn Deutschland und Frankreich zusammenarbeiten und wenn wir uns alle am Riemen reißen und diese Zusammenarbeit mit Leben erfüllen.
#
#  0.0
# ({4})
#
#  0.0
# Ein letzter Punkt – ich weiß, dass es viele Kolleginnen und Kollegen gibt, die das mit großem Engagement verfolgen – ist die Zusammenarbeit in den sogenannten Grenzregionen. 0.0
# Am Ende geht es vor allem darum: 0.0
# Gelingt es uns, dass die Grenze im Alltag der Menschen gänzlich unsichtbar wird? 0.0
# In den Bereichen Gesundheit, Brandschutz, Sicherheit, Bildung, Qualifizierung wollen wir als Bundesländer, als Kommunen, als Kreise, als Regionen und Departements deutlich machen: 0.0
# Es gelingt, und Europa wird besser, wenn Grenzen verschwinden.
#
#  0.0
# Deshalb bitte ich Sie im Namen der Bundesregierung um Ihre engagierte Debatte – die kommt ja gleich noch – und um Ihre Unterstützung.
#
#  0.0
# Vielen Dank.
#
#  0.0
# ({5}) 0.0
#
#
#  0.0
# Gestatten Sie eine Zwischenfrage? 0.0
#
#
# Nächster Redner ist der Kollege Alexander Dobrindt, CDU/CSU.
#
#  0.0
# ({0}) 0.0
#
#
#  0.0
# Jetzt erteile ich das Wort dem Fraktionsvorsitzenden der Linken, Dr. Dietmar Bartsch.
#
#  0.0
# ({0}) 0.0
#
#
# Herr Präsident! 0.0
# Meine Damen und Herren! 0.0
# 70 Jahre Grundgesetz sind zu Recht ein Anlass, über das Grundgesetz, über Deutschland, über seine Geschichte, aber auch über seine Gegenwart hier im Plenum würdigend zu debattieren und nachzudenken. 0.0
# Entscheidend ist: Das Grundgesetz ist die Antwort auf den und eine praktische Lehre aus dem Zivilisationsbruch der Nationalsozialisten. 0.0
# „Die Würde des Menschen ist unantastbar“ als der zentrale Satz
#
# ({0})
#
# ist eine Antwort auf ein Regime, für das „Menschenwürde“ ein Fremdwort war.
#
#  0.0
# Vor fünf Jahren hat hier, an dieser Stelle, der von mir sehr geschätzte Navid Kermani zum 65. Jahrestag des Grundgesetzes eine berührende Rede gehalten.
#
#  0.0
# ({1})
#
#  0.0
# Er wies darauf hin, dass der Satz „Die Würde des Menschen ist unantastbar“ paradox sei; 0.0
# denn wenn sie unantastbar sei, müsste es ja nicht festgeschrieben werden. 0.0
# Und er hat recht. 0.0
# Der industrielle Massenmord an den europäischen Jüdinnen und Juden und der Vernichtungskrieg im Osten waren grausame Höhepunkte dieses Ge­waltregimes und haben gezeigt, dass ein Staat den Verstoß gegen die Menschenwürde zum Prinzip erheben kann.
#
#  0.0
# Es muss daran erinnert werden, dass die Deutschen nicht in der Lage waren, die sogenannte Machtergreifung der Nazis zu verhindern. 0.0
# Sie waren auch nicht in der Lage, deren Herrschaft aus eigener Kraft abzuschütteln. 0.0
# Befreiung war nur von außen möglich – durch den Sieg der Streitkräfte der Anti-Hitler-Koalition. 0.0
# Menschen überall in der Welt zahlten für unsere Befreiung einen hohen Preis. 0.0
# Letzte Woche haben wir dieses Tages der Befreiung gedacht, und es war, meine Damen und Herren, ein Tag der Befreiung – das muss man immer wieder betonen, und das sollten auch alle Abgeordneten des Deutschen Bundestages immer wieder betonen –,
#
# ({2})
#
# der Befreiung von einer Politik der Unmenschlichkeit. 0.0
# Dass Politik auf die systematische Zerstörung der Menschlichkeit hinausläuft, das dürfen wir alle nie wieder zulassen.
#
#  0.0
# ({3})
#
#  0.0
# Gerade deswegen ist es so wichtig, die Tragweite des Artikels 1 zu verstehen. 0.0
# Er ist ein Versprechen, das jeden Tag aufs Neue eingelöst werden muss. 0.0
# Dieser Satz muss als Auftrag an die konkrete Gesellschaftsgestaltung verstanden werden. 0.0
# Der Geist des Grundgesetzes ist ein radikaler Bruch mit dem Faschismus. 0.0
# Die Mütter und Väter des Grundgesetzes haben genau gewusst, dass der Kampf gegen den Faschismus umfassend sein muss, dass ein Bekenntnis zur Unantastbarkeit der Würde des Menschen nicht reicht, dass dieses Bekenntnis im Staat verankert sein muss.
#
#  0.0
# Der Geist des Grundgesetzes verpflichtet uns deswegen, auch eine soziale Politik zu machen, einen solidarischen Staat und eine solidarische Gesellschaft zu gestalten. 0.0
# Das Grundgesetz ist ein Bekenntnis zur sozialen Demokratie, lieber Christian Lindner. 0.0
# Im Artikel 20 des Grundgesetzes heißt es nicht umsonst:
#
# Die Bundesrepublik Deutschland ist ein demokratischer und sozialer Bundesstaat.
#
# ({4})
#
#  0.0
# Die Bundesrepublik wurde mit diesem Artikel als sozialer Rechtsstaat definiert. 0.0
# Artikel 79 Absatz 3 stellt, wie wir alle wissen, diese Definition unter den Schutz der Ewigkeitsklausel. 0.0
# Das zeigt, wie zentral die soziale Demokratie im Grundgesetz ist. 0.0
# Deswegen findet sich neben der Eigentumsgarantie auch deren Einschränkung durch Gemeinwohl bzw. die sogenannte Sozialpflichtigkeit in Artikel 14.
#
# ({5})
#
#  0.0
# Die Mütter und Väter des Grundgesetzes wussten ganz genau, dass eine allzu große soziale Spaltung die Gesellschaft gefährdet. 0.0
# Es ist doch auch kein Zufall, wenn im Koalitionsvertrag steht: „Ein neuer Zusammenhalt für unser Land“. 0.0
# Das sagt vor allen Dingen eins, dass es offensichtlich Defizite im sozialen Zusammenhalt gibt.
#
#  0.0
# ({6})
#
# Tatsächlich ist die Gesellschaft sozial gespalten wie seit Jahrzehnten nicht. 0.0
# Die Republik und auch das Grundgesetz werden aktuell auf eine Bewährungsprobe gestellt; 0.0
# denn mittlerweile ist die Unantastbarkeit der Menschenwürde leider infrage gestellt. 0.0
# Es gibt sogar Zehntausende Men schen, die das Grundgesetz als Verfassung infrage stellen. 0.0
# Wir alle haben gesehen: Wenn in Plauen Rechtsextreme marschieren, dann ist das ein Wiedergänger jenes Faschismus, den wir alle längst erledigt glaubten.
#
#  0.0
# ({7})
#
#  0.0
# Aber es ist nicht nur die Reinkarnation des Nationalsozialismus, die das Grundgesetz auf die Probe stellt. 0.0
# Eine Gefahr ist auch die neoliberale Umgestaltung unserer Gesellschaft und des Staates. 0.0
# Der Neoliberalismus will eine andere Demokratie als das Grundgesetz. 0.0
# Ich will mal die – Zitat – „marktkonforme Demokratie“ hier erwähnen. 0.0
# Die „marktkonforme Demokratie“ unterwirft die Demokratie und die Menschenrechte der Verwertungslogik – und das kann letztlich die soziale Demokratie zerstören, meine Damen und Herren.
#
#  0.0
# ({8})
#
#  0.0
# In einer sozialen Demokratie geht es stattdessen darum, den Kapitalismus dort, wo er Demokratie zerstört, einzuhegen. 0.0
# Dieses Einhegungsprojekt ist aber schon lange kein Thema mehr in der Politik in Deutschland, obwohl das Grundgesetz, die Verfassung, darauf angelegt ist. 0.0
# Das ist im Übrigen auch der Sinn, lieber Christian Lindner, von Artikel 15, den Sie für sozialistisch halten. 0.0
# Für andere ist er ein Relikt. 0.0
# Aber: Es geht darum, zu vergesellschaften, wenn andere Steuerungsinstrumente versagen. 0.0
# Das ist der Sinn, der dort festgehalten wird.
#
#  0.0
# ({9})
#
#  0.0
# Dass das Thema Vergesellschaftung selbst heute hier zu so hysterischen Reaktionen führt, dass viele neoliberale Glaubenssätze nicht mal mehr auch nur hinterfragt werden dürfen, das finde ich, ehrlich gesagt, grotesk. 0.0
# Die Debatten der letzten Wochen und die wirklich hysterischen Schreie auch einiger hier aus dem Haus haben gezeigt, wie beschränkt viele mittlerweile sind, über Wirtschaft und Gesellschaft abseits vom Turbokapitalismus nachzudenken.
#
#  0.0
# ({10})
#
#  0.0
# Da ist das Grundgesetz offener, kreativer als manche Debattenbeiträge der letzten Wochen. 0.0
# Statt die Lehren, die im Grundgesetz verankert sind, ernst zu nehmen, wird bei jedem Anlass schnell die Änderung des Grundgesetzes gefordert. 0.0
# Ich will Herrn Harbarth – unlängst noch in diesem Hause – zitieren, der in der „FAZ“ diese Woche ein bemerkenswertes Interview gegeben hat. 0.0
# Er hat gesagt: Ob jede der über 60 Änderungen des Grundgesetzes sinnvoll war, will er bezweifeln.  0.0
# – Ich will dem gerne folgen und zum Beispiel an das Asylrecht und andere Dinge erinnern, wo wir das Grundgesetz nicht unbedingt verbessert haben.
#
#  0.0
# ({11})
#
# Deswegen, meine Damen und Herren, haben mich die sehr leichtfertigen Forderungen, Artikel 15 abzuschaffen, ehrlich gesagt, entsetzt. 0.0
# Ich finde das anmaßend. 0.0
# Insbesondere die ersten 20 Artikel sind doch nicht einfach mal so abzuschaffen.
#
#  0.0
# ({12})
#
#  0.0
# Europa und das Grundgesetz sind kein Widerspruch. 0.0
# Im Gegenteil, wer die Einbindung Europas rückabwickeln will, steht eben nicht auf dem Boden unseres Grundgesetzes. 0.0
# Wer einen deutschen Sonderweg fordert, handelt gegen den Geist unserer Verfassung.
#
#  0.0
# ({4})
#
#  0.0
# Die Präambel des Grundgesetzes ist seit 1990 eine andere als 1949. 0.0
# Denn in der Fassung von 1949 hieß es noch:
#
# Es hat auch für jene Deutschen gehandelt, denen mitzuwirken versagt war.
#
#  0.0
# Liebe Kolleginnen und Kollegen, welch ein Glück, dass wir im Jahr 1990 nach so langen Jahren der Teilung die Einheit unseres Vaterlandes vollenden konnten.
#
#  0.0
# ({5})
#
# Diesen Weg zur Einheit hat das Grundgesetz von 1949 vorgezeichnet. 0.0
# Erkämpft worden ist er aber in der friedlichen Revolution von 1989 durch das Engagement und vor allen Dingen den Wagemut der Bürgerinnen und Bürger der damaligen DDR.
#
#  0.0
# ({6})
#
#  0.0
# So kann man sagen: 0.0
# Unser Land hat sich mit oder gerade durch das Grundgesetz in einer Weise entwickelt, die die Hoffnung der Deutschen vor 70 Jahren bei weitem übersteigen: wiedervereint, respektiert und anerkannt in der Gemeinschaft der Völker, Bestandteil eines gemeinsamen Europas, wirtschaftlich erfolgreich und trotz allem immer noch mit einer stabilen Gesellschaftsstruktur.
#
#  0.0
# Das Grundgesetz war als Provisorium gedacht. 0.0
# Entsprechend nüchtern ist es formuliert, einige schreiben: „karg“, aber, so meine ich, gerade deswegen dauerhafter als viele andere ambitionierte Verfassungsentwürfe. 0.0
# Heute, 70 Jahre nach seiner Verkündung, stößt das Grundgesetz auf eine sehr gute Resonanz in der Bevölkerung. 0.0
# Es ist populär. 0.0
# Seine klare Sprache, seine weitgehende Reduktion auf das Wesentliche machen es – so wird zu Recht gesagt – zeitlos.
#
#  0.0
# Aber: Das Grundgesetz steht nicht unantastbar auf dem Sockel. 0.0
# Deshalb ist es richtig, dass wir heute hier im Parlament keine Gedenkstunde feiern, sondern über unsere Verfassung debattieren. 0.0
# Wir haben eine lebende Verfassung. 0.0
# 63-mal wurde das Grundgesetz geändert – nicht immer nur zum Positiven, wenn ich an den einen oder anderen eingefügten Buchstabenartikel denke. 0.0
# Und es besteht weiterhin der Wunsch, das Grundgesetz zu ändern und zu ergänzen. 0.0
# Ich denke, das ist auch richtig. 0.0
# Trotzdem rate ich zur Vorsicht. 0.0
# Die DNA, die dieses Grundgesetz erfolgreich gemacht hat, muss erhalten werden, und dazu gehört zumindest im Grundrechtsteil die Beschränkung auf das Wesentliche. 0.0
# Eine weitere zeitgeistgetriebene Anreicherung von Staatszielen oder gar der Grundrechte macht das Grundgesetz sicherlich nicht besser.
#
#  0.0
# ({7})
#
# Insofern halte ich wenig davon, alles und jedes, mag es auf den ersten Blick noch so sinnvoll erscheinen, in den Verfassungsrang zu erheben.
#
#  0.0
# Die Werte des Grundgesetzes, von der Würde des Menschen über den Schutz des Eigentums bis zum Schutz des Fernmeldegeheimnisses – ja, das steht auch darin –, sind im Übrigen zukunftsoffen und gelten auch für das sogenannte Neuland. 0.0
# Meine Damen und Herren, das Internet ist kein rechts- und schon gar kein grundrechtsfreier Raum und darf es auch nicht werden.
#
#  0.0
# ({8})
#
# Abwehrrechte ebenso wie Schutzpflichten des Staates zur Einhaltung der Rechte anderer gelten hier in gleicher Weise wie in der analogen Welt. 0.0
# Alles andere würde nämlich bedeuten, dass wesentliche Teile unseres Lebens eben nicht mehr von einer demokratisch legitimierten Verfassung geschützt würden.
#
#  0.0
# Alles gut also? 0.0
# Keine Herausforderungen? 0.0
# Kann dann doch alles so bleiben, wie es ist? 0.0
# Natürlich nicht. 0.0
# Ich möchte einige Punkte benennen, über die wir in den nächsten Monaten und Jahren dringend reden müssen:
#
#  0.0
# Erstens. 0.0
# Das einzig direkt gewählte Verfassungsorgan – bei allem Respekt – ist das Parlament, ist der Deutsche Bundestag. 0.0
# Gerade in Zeiten von großen Koalitionen sollten wir als Parlament deswegen auch sehr selbstbewusst agieren. 0.0
# Gesetze werden vom Parlament gemacht, und das müssen wir tagtäglich auch so leben. 0.0
# Das bedeutet auch, dass Gesetzentwürfe der Bundesregierung nicht in Stein gemeißelt sind. 0.0
# Denn hier im Parlament ist der Ort der politischen Auseinandersetzung, an dem wir offen und transparent die beste Lösung für unser Land suchen sollen.
#
#  0.0
# ({9})
#
#  0.0
# Zweitens. 0.0
# Das Grundgerüst des Föderalismus stammt aus dem Jahr 1949 mit all seinen Besonderheiten. 0.0
# Seitdem stand die Reform der bundesstaatlichen Ordnung mehrfach auf der Agenda. 0.0
# ...
#
#  0.0
# ({6})
#
#  0.0
# Das ist wichtig, um eine gute Versorgung der Kolleginnen und Kollegen in der Paketbranche – Stichwort: Sozialversicherung – sicherzustellen.
#
#  0.0
# Noch einmal zu der Frage, ob ich Ihren Antrag gelesen habe. 0.0
# Sie sollten ein bisschen besser recherchieren, Frau Dröge. 0.0
# Sie kritisieren dort nämlich, dass auf dem deutschen Markt nicht die gleichen arbeitsrechtlichen Bedingungen für Kolleginnen und Kollegen aus dem Ausland herrschen. 0.0
# Frau Dröge, ich empfehle Ihnen, einfach einmal in die Entsenderichtlinie der Europäischen Union aus dem Mai 2018 zu schauen. 0.0
# Denn dort heißt es: Gleicher Lohn für gleiche Arbeit am gleichen Ort.
#
# ({7})
#
#  0.0
# Das, meine Damen und Herren, ist richtig und wichtig und eine gute Absicherung für gute Arbeit in Deutschland.
#
# ({8})
#
# Wir müssen also nicht mehr Wettbewerb fordern, sondern wir müssen die Tariftreue stärken. 0.0
# Wir müssen vielleicht sogar darüber nachdenken – ich habe das an anderer Stelle schon erwähnt –, die Unternehmen, die eine gute Mitbestimmung haben, so zu stärken, dass es für alle Unternehmen entsprechend attraktiv ist, gute tarifliche Absicherung für die Kolleginnen und Kollegen zu erbringen.
#
#  0.0
# Meine Kolleginnen und Kollegen von der FDP, Sie fordern die vollständige Privatisierung der Post.
#
#  0.0
# ({9})
#
# Wir sind es ja von Ihnen gewohnt, dass Sie alles privatisieren wollen.
#
#  0.0
# ({10})
#
# Ich sage Ihnen noch einmal das, was ich eben schon erwähnt habe: Wir erleben beispielsweise bei der Deutschen Bahn, was als Folge der Teilprivatisierung passiert ist.
#
#  0.0
# ({11})
#
#  0.0
# Das Ergebnis ist, dass Strecken im ländlichen Raum stillgelegt wurden.
#
#  0.0
# ({12})
#
# – Sie melden sich bitte, um eine Zwischenfrage zu stellen, oder der Kollege, der gleich redet, kann es ausführen.  0.0
# – Dort gab es einen stärkeren Wettbewerb auf der Schiene. 0.0
# Das hat zu einem erhöhten Kostendruck geführt. 0.0
# Das führt dazu, dass im ländlichen Raum Strecken stillgelegt werden.
#
#  0.0
# ({13})
#
#  0.0
# Die Folge ist, dass beispielsweise der Service im öffentlichen Personenverkehr zwischen Stadt und dem ländlichen Raum auseinanderklafft. 0.0
# Wenn Sie das auch bei der Post wollen, dann bekennen Sie Farbe. 0.0
# Sagen Sie das, wenn das die Folge Ihrer Privatisierungsfantasien sein soll.
#
#  0.0
# ({14})
#
# Für uns steht fest: Wir wollen eine flächendeckende Post mit tariflich gut abgesicherten Arbeitsplätzen. 0.0
# Das hat für uns höchste Priorität. 0.0
# Insofern, meine Damen und Herren, freue ich mich auf die Beratungen in den Ausschüssen.
#
#  0.0
# Herzlichen Dank.
#
#  0.0
# ({15}) 0.0
#
#
#  0.0
# Für die FDP-Fraktion hat das Wort der Kollege Reinhard Houben.
#
#  0.0
# ({0}) 0.0
#
#
#  0.0
# Für Bündnis 90/Die Grünen hat das Wort die Kollegin Beate Müller-Gemmeke.
#
#  0.0
# ({0}) 0.0
#
#
#  0.0
# Sehr geehrter Herr Präsident! 0.0
# Sehr geehrte Kolleginnen und Kollegen! 0.0
# Sehr geehrte Gäste! 0.0
# Bisher ging die Debatte vor allem um den Postmarkt. 0.0
# Ich konzentriere mich jetzt ganz auf die Paketbranche; 0.0
# denn hier geht der Wettbewerb voll und ganz zulasten der Beschäftigten.
#
#  0.0
# Die Branche ist ein schwer zu durchschauendes Geflecht aus zahlreichen Sub-Sub-Sub-Unternehmen, geprägt durch Leiharbeit, Werkverträge und Scheinselbstständigkeit. 0.0
# Der Anstand geht häufig ganz verloren, wenn es um entsandte Beschäftigte geht, insbesondere aus den osteuropäischen Staaten. 0.0
# Sie arbeiten teilweise ohne Arbeitsvertrag, ohne Sozialversicherung; 0.0
# das Arbeitszeitgesetz wird missachtet. 0.0
# Die Schwerpunktkon­trollen im Februar haben gezeigt: 0.0
# Jedes dritte Subunternehmen bezahlt zu wenig Lohn. 0.0
# Fairer Wettbewerb und faire Arbeitsbedingungen sehen anders aus.
#
#  0.0
# ({0})
#
# Deshalb fordern wir schon lange eine Nachunternehmerhaftung für Sozialversicherungsbeiträge, damit sich die großen Paketfirmen nicht mehr länger aus der Verantwortung stehlen können. 0.0
# Herr Kollege Mohrs, das ändert rein gar nichts an der Scheinselbstständigkeit, weil es hier rein um Beschäftigung geht. 0.0
# Dazu hat sich die Bundesregierung zum Glück endlich durchgerungen – nach langem Streit und gegenseitiger Blockade.
#
#  0.0
# ({1})
#
# Jetzt wird hoffentlich die Nachunternehmerhaftung in der Paketbranche kommen. 0.0
# Das ist gut. 0.0
# Jetzt müssen Sie aber auch erst einmal liefern.
#
#  0.0
# ({2})
#
#  0.0
# Das reicht aber noch nicht aus. 0.0
# Die Arbeitszeit muss wie in der Fleischbranche täglich dokumentiert werden, damit die Finanzkontrolle Schwarzarbeit effektiv kontrollieren kann. 0.0
# Nur so macht im Übrigen die Nachunternehmerhaftung wirklich Sinn.
#
#  0.0
# ({3})
#
#  0.0
# Wir brauchen auch mehr Kontrollen. 0.0
# Deshalb braucht die Finanzkontrolle Schwarzarbeit mehr Personal. 0.0
# Herr Kollege Mohrs, noch einmal: 0.0
# Finanzminister Scholz kündigt zwar immer und immer wieder neue Stellen an. 0.0
# Die kommen aber nicht an. 0.0
# Die 1 600 Stellen von 2014 zur Kontrolle des Mindestlohns sind bei der Finanzkontrolle noch nicht einmal besetzt. 0.0
# Also bleiben Sie bitte endlich bei den Tatsachen.
#
#  0.0
# ({4})
#
# Ganz wichtig für uns ist noch – das steht auch im Antrag –: 0.0
# Die Beschäftigten brauchen Unterstützung; 0.0
# denn sie bekommen häufig ihren Lohn nur über den Klageweg. 0.0
# Allein gegen den Arbeitgeber zu klagen, ist ein steiniger Weg. 0.0
# Deshalb fordern wir einen kollektiven Rechtsschutz, ein Verbandsklagerecht. 0.0
# Das nimmt den Druck von den Beschäftigten, und das eröffnet vor allem auch die Chance, die strukturelle Arbeitsausbeutung Schritt für Schritt zu bekämpfen.
#
#  0.0
# Das alles ist dringend notwendig – ich bin gespannt, ob die SPD das auch liefert –; 0.0
# denn alle Beschäftigten haben verdient, dass sie fair bezahlt und gut behandelt werden.
#
#  0.7
# Vielen Dank.
#
#  0.0
# ({5}) 0.0
#
#
# Herr Präsident! 0.0
# Meine Damen und Herren! 0.0
# Herr Mohrs, ich glaube, Sie sind der Einzige in diesem Hause, der es so wahrgenommen hat, dass die Deutsche Bahn privatisiert worden ist.
#
# ({0})
#
#  0.0
# Das ist ein zu 100 Prozent staatliches Unternehmen. 0.0
# All Ihre Kritik, die Sie hier vollkommen zu Recht vortragen, trifft natürlich den Eigentümer, nämlich die Bundesrepublik Deutschland und damit diese Bundesregierung.
#
#  0.0
# ({1})
#
# Sie sollten vielleicht einmal mit dem Kollegen Scheuer – er ist der Verkehrsminister – sprechen. 0.0
# An der Stelle könnten Sie die Vorwürfe, was die Deutsche Bahn angeht, vortragen. 0.0
# Wir könnten da bestimmt noch einige Anregungen geben.  0.0
# – Entschuldigung, das musste ich mal loswerden.
#
#  0.0
# ({2})
#
# Zweite Bemerkung. 0.0
# Wettbewerb bringt auch Innovation. 0.0
# Günter Rexrodt hat vor 25 Jahren die Postprivatisierung begonnen. 0.0
# Sie ist leider nicht komplett bis zum Ende durchgeführt worden. 0.0
# Was hat denn die Privatisierung der Post gebracht?
#
# ({3})
#
# Der sogenannte graue Postmarkt, also die Telekommunikation, ist privatisiert worden. 0.0
# Früher hatten wir Wählscheiben- und Tastentelefone. 0.0
# Die gab es, glaube ich, auch in moosgrün; 0.0
# das war die Innovation.
#
#  0.0
# ({4})
#
#  0.0
# Dann sanken die Preise, es wurden neue Produkte angeboten, es wurden mehr Arbeitsplätze geschaffen, es wurden höherwertige Arbeitsplätze geschaffen. 0.0
# Wir haben durch diese Privatisierung einen Aufschwung bekommen. 0.0
# Jeder hat am Ende des Tages davon profitiert,
#
# ({5})
#
# nur vielleicht nicht einige Beamte aus dem ehemaligen Postministerium, Herr Mohrs. 0.0
# Deswegen kann ich das, was Sie sagten, nicht verstehen.
#
#  0.0
# ({6}) 0.0
#
#
# Herr Kollege, gestatten Sie eine Zwischenfrage des Kollegen Lenkert? 0.0
#
#
#  0.0
# Ja, Herr Lenkert, bitte. 0.0
#
#
#  0.0
# Herr Kollege Houben, ist Ihnen bekannt, dass in den Jahren 1990/91 eine technische Revolution stattfand, die dazu führte, dass im Prinzip die alten Wähltelefone technisch ganz einfach abgelöst werden konnten durch die neueren Systeme, die deutlich billiger sind in Wartung, Installation und Betrieb? 0.0
# Diese Innovation wurde nicht von dem von Ihnen so hoch gelobten Telekommunikationsunternehmen in Deutschland ausgelöst, sondern von einem Industriekonzern aus Finnland und asiatischen Konzernen, wo diese neue Technologie entwickelt wurde. 0.0
# Ist Ihnen das bekannt? 0.0
# Können Sie nachvollziehen, dass diese technische Innovation die Preissenkung mit sich gebracht hat und nicht die Privatisierung?
#
# ({0}) 0.0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[45], line 2
#       1 for beitrag in beitraege:
# ----> 2     doc = nlp(beitrag)
#       3     for span in doc.sents:
#       4         print(span.text, span._.polarity)
#
# File ~\anaconda3\Lib\site-packages\spacy\language.py:1011, in Language.__call__(self, text, disable, component_cfg)
#    1009     error_handler = proc.get_error_handler()
#    1010 try:
# -> 1011     doc = proc(doc, **component_cfg.get(name, {}))  # type: ignore[call-arg]
#    1012 except KeyError as e:
#    1013     # This typically happens if a component is not initialized
#    1014     raise ValueError(Errors.E109.format(name=name)) from e
#
# File ~\anaconda3\Lib\site-packages\spacy\pipeline\trainable_pipe.pyx:52, in spacy.pipeline.trainable_pipe.TrainablePipe.__call__()
#
# File ~\anaconda3\Lib\site-packages\spacy\pipeline\transition_parser.pyx:253, in spacy.pipeline.transition_parser.Parser.predict()
#
# File ~\anaconda3\Lib\site-packages\spacy\pipeline\transition_parser.pyx:274, in spacy.pipeline.transition_parser.Parser.greedy_parse()
#
# File ~\anaconda3\Lib\site-packages\thinc\model.py:315, in Model.predict(self, X)
#     311 def predict(self, X: InT) -> OutT:
#     312     """Call the model's `forward` function with `is_train=False`, and return
#     313     only the output, instead of the `(output, callback)` tuple.
#     314     """
# --> 315     return self._func(self, X, is_train=False)[0]
#
# File ~\anaconda3\Lib\site-packages\spacy\ml\tb_framework.py:33, in forward(model, X, is_train)
#      32 def forward(model, X, is_train):
# ---> 33     step_model = ParserStepModel(
#      34         X,
#      35         model.layers,
#      36         unseen_classes=model.attrs["unseen_classes"],
#      37         train=is_train,
#      38         has_upper=model.attrs["has_upper"],
#      39     )
#      41     return step_model, step_model.finish_steps
#
# File ~\anaconda3\Lib\site-packages\spacy\ml\parser_model.pyx:213, in spacy.ml.parser_model.ParserStepModel.__init__()
#
# File ~\anaconda3\Lib\site-packages\thinc\model.py:291, in Model.__call__(self, X, is_train)
#     288 def __call__(self, X: InT, is_train: bool) -> Tuple[OutT, Callable]:
#     289     """Call the model's `forward` function, returning the output and a
#     290     callback to compute the gradients via backpropagation."""
# --> 291     return self._func(self, X, is_train=is_train)
#
# File ~\anaconda3\Lib\site-packages\thinc\layers\chain.py:55, in forward(model, X, is_train)
#      53 callbacks = []
#      54 for layer in model.layers:
# ---> 55     Y, inc_layer_grad = layer(X, is_train=is_train)
#      56     callbacks.append(inc_layer_grad)
#      57     X = Y
#
# File ~\anaconda3\Lib\site-packages\thinc\model.py:291, in Model.__call__(self, X, is_train)
#     288 def __call__(self, X: InT, is_train: bool) -> Tuple[OutT, Callable]:
#     289     """Call the model's `forward` function, returning the output and a
#     290     callback to compute the gradients via backpropagation."""
# --> 291     return self._func(self, X, is_train=is_train)
#
# File ~\anaconda3\Lib\site-packages\thinc\layers\chain.py:55, in forward(model, X, is_train)
#      53 callbacks = []
#      54 for layer in model.layers:
# ---> 55     Y, inc_layer_grad = layer(X, is_train=is_train)
#      56     callbacks.append(inc_layer_grad)
#      57     X = Y
#
#     [... skipping similar frames: Model.__call__ at line 291 (1 times)]
#
# File ~\anaconda3\Lib\site-packages\thinc\layers\chain.py:55, in forward(model, X, is_train)
#      53 callbacks = []
#      54 for layer in model.layers:
# ---> 55     Y, inc_layer_grad = layer(X, is_train=is_train)
#      56     callbacks.append(inc_layer_grad)
#      57     X = Y
#
# File ~\anaconda3\Lib\site-packages\thinc\model.py:291, in Model.__call__(self, X, is_train)
#     288 def __call__(self, X: InT, is_train: bool) -> Tuple[OutT, Callable]:
#     289     """Call the model's `forward` function, returning the output and a
#     290     callback to compute the gradients via backpropagation."""
# --> 291     return self._func(self, X, is_train=is_train)
#
# File ~\anaconda3\Lib\site-packages\thinc\layers\with_array.py:37, in forward(model, Xseq, is_train)
#      33 def forward(
#      34     model: Model[SeqT, SeqT], Xseq: SeqT, is_train: bool
#      35 ) -> Tuple[SeqT, Callable]:
#      36     if isinstance(Xseq, Ragged):
# ---> 37         return cast(Tuple[SeqT, Callable], _ragged_forward(model, Xseq, is_train))
#      38     elif isinstance(Xseq, Padded):
#      39         return cast(Tuple[SeqT, Callable], _padded_forward(model, Xseq, is_train))
#
# File ~\anaconda3\Lib\site-packages\thinc\layers\with_array.py:92, in _ragged_forward(model, Xr, is_train)
#      88 def _ragged_forward(
#      89     model: Model[SeqT, SeqT], Xr: Ragged, is_train: bool
#      90 ) -> Tuple[Ragged, Callable]:
#      91     layer: Model[ArrayXd, ArrayXd] = model.layers[0]
# ---> 92     Y, get_dX = layer(Xr.dataXd, is_train)
#      94     def backprop(dYr: Ragged) -> Ragged:
#      95         return Ragged(get_dX(dYr.dataXd), dYr.lengths)
#
# File ~\anaconda3\Lib\site-packages\thinc\model.py:291, in Model.__call__(self, X, is_train)
#     288 def __call__(self, X: InT, is_train: bool) -> Tuple[OutT, Callable]:
#     289     """Call the model's `forward` function, returning the output and a
#     290     callback to compute the gradients via backpropagation."""
# --> 291     return self._func(self, X, is_train=is_train)
#
# File ~\anaconda3\Lib\site-packages\thinc\layers\chain.py:55, in forward(model, X, is_train)
#      53 callbacks = []
#      54 for layer in model.layers:
# ---> 55     Y, inc_layer_grad = layer(X, is_train=is_train)
#      56     callbacks.append(inc_layer_grad)
#      57     X = Y
#
# File ~\anaconda3\Lib\site-packages\thinc\model.py:291, in Model.__call__(self, X, is_train)
#     288 def __call__(self, X: InT, is_train: bool) -> Tuple[OutT, Callable]:
#     289     """Call the model's `forward` function, returning the output and a
#     290     callback to compute the gradients via backpropagation."""
# --> 291     return self._func(self, X, is_train=is_train)
#
# File ~\anaconda3\Lib\site-packages\thinc\layers\chain.py:55, in forward(model, X, is_train)
#      53 callbacks = []
#      54 for layer in model.layers:
# ---> 55     Y, inc_layer_grad = layer(X, is_train=is_train)
#      56     callbacks.append(inc_layer_grad)
#      57     X = Y
#
# File ~\anaconda3\Lib\site-packages\thinc\model.py:291, in Model.__call__(self, X, is_train)
#     288 def __call__(self, X: InT, is_train: bool) -> Tuple[OutT, Callable]:
#     289     """Call the model's `forward` function, returning the output and a
#     290     callback to compute the gradients via backpropagation."""
# --> 291     return self._func(self, X, is_train=is_train)
#
# File ~\anaconda3\Lib\site-packages\thinc\layers\layernorm.py:25, in forward(model, X, is_train)
#      24 def forward(model: Model[InT, InT], X: InT, is_train: bool) -> Tuple[InT, Callable]:
# ---> 25     N, mu, var = _get_moments(model.ops, X)
#      26     Xhat = (X - mu) * var ** (-1.0 / 2.0)
#      27     Y, backprop_rescale = _begin_update_scale_shift(model, Xhat)
#
# File ~\anaconda3\Lib\site-packages\thinc\layers\layernorm.py:75, in _get_moments(ops, X)
#      73 def _get_moments(ops: Ops, X: Floats2d) -> Tuple[Floats2d, Floats2d, Floats2d]:
#      74     # TODO: Do mean methods
# ---> 75     mu: Floats2d = X.mean(axis=1, keepdims=True)
#      76     var: Floats2d = X.var(axis=1, keepdims=True) + 1e-08
#      77     return cast(Floats2d, ops.asarray_f([X.shape[1]])), mu, var
#
# File ~\anaconda3\Lib\site-packages\numpy\core\_methods.py:118, in _mean(a, axis, dtype, out, keepdims, where)
#     115         dtype = mu.dtype('f4')
#     116         is_float16_result = True
# --> 118 ret = umr_sum(arr, axis, dtype, out, keepdims, where=where)
#     119 if isinstance(ret, mu.ndarray):
#     120     with _no_nep50_warning():
#
# KeyboardInterrupt:

# %%
doc._.blob.sentiment_assessments.assessments
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[46], line 1
# ----> 1 doc._.blob.sentiment_assessments.assessments
#
# AttributeError: 'NoneType' object has no attribute 'sentiment_assessments'

# %%
doc._.blob.ngrams()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[47], line 1
# ----> 1 doc._.blob.ngrams()
#
# AttributeError: 'NoneType' object has no attribute 'ngrams'

# %%
# Analyse der Texte und Sammeln der Sentimentinformationen
sentiments = []

for beitrag in beitraege:
    doc = nlp(beitrag)
    sentiment = {
        'text': text,
        'polarity': doc._.polarity,
        'subjectivity': doc._.subjectivity,
    }
    sentiments.append(sentiment)
print(sentiments)
# Zusammenfassung der Sentimentinformationen
total_texts = len(sentiments)
positive_texts = sum(1 for s in sentiments if s['polarity'] > 0)
negative_texts = sum(1 for s in sentiments if s['polarity'] < 0)
neutral_texts = total_texts - positive_texts - negative_texts

# Durchschnittliche Polarisierung und Subjektivität
average_polarity = sum(s['polarity'] for s in sentiments) / total_texts
average_subjectivity = sum(s['subjectivity'] for s in sentiments) / total_texts

# Ausgabe der Zusammenfassung
print(f"Gesamtanzahl der analysierten Texte: {total_texts}")
print(f"Positive Texte: {positive_texts}")
print(f"Negative Texte: {negative_texts}")
print(f"Neutrale Texte: {neutral_texts}")
print(f"Durchschnittliche Polarisierung: {average_polarity}")
print(f"Durchschnittliche Subjektivität: {average_subjectivity}")
# Out:
# [{'text': '\n\nHerr Präsident! Liebe Kolleginnen und Kollegen! Liebe Zuhörerinnen und Zuhörer auf den Tribünen! Jetzt haben wir etwas für juristische Feinschmecker zu beraten: ein sehr wichtiges Gesetz, das wir unbedingt beschließen müssen, wenn wir schlimme Zustände in den Justizvollzugsanstalten verhindern wollen.\n\nDas Bundesverfassungsgericht hat im Juli\xa02018 das bayerische Unterbringungsgesetz und das baden-württembergische Gesetz über Hilfen und Schutzmaßnahmen bei psychischen Krankheiten für verfassungswidrig erklärt. Wie ich finde, hat das Bundesverfassungsgericht zu Recht bemängelt, dass es in diesen Gesetzen keine ausreichende Grundlage für die Anordnung von Fixierungen gibt und insbesondere keine richterliche Überprüfung vorgesehen ist.\n\nEs geht dabei um Fälle, in denen die Bewegungsfreiheit\xa0– etwa von Patienten oder von Strafgefangenen\xa0– vollständig aufgehoben wird. Darin sah das Verfassungsgericht einen so großen Eingriff in die Freiheitsrechte der betroffenen Fixierten, dass es für diese Maßnahmen eine richterliche Anordnung fordert. Dieser Forderung des Verfassungsgerichtes kommen wir mit diesem Gesetz nach, und wir regeln die Voraussetzungen für das Verfahren zur Anordnung einer solchen Fixierung.\n\nIm Einvernehmen mit den Ländern schaffen wir hierfür im Strafvollzug eine bundeseinheitliche Regelung, die ansonsten die Länder schaffen müssen. Dabei machen wir, wie ich finde, drei wichtige Dinge:\n\nErstens. Wir sichern die Grundrechte der Fixierten.\n\nZweitens. Wir schaffen klare Vorgaben für die Ärzte, für die Ärztinnen und auch für die Richter zur Anordnung und zur Vornahme dieser Fixierungen.\n\nDrittens. Durch klare Regelungen machen wir diese Fixierungen möglich, und das dient dem Schutz der Mitarbeiterinnen und Mitarbeiter für den Fall der Fälle in den Gefängnissen oder auch in den psychiatrischen Anstalten.\n\nDas sind drei ganz wichtige Aspekte.\n\n({0})\n\nKonkret regeln wir mit diesem Gesetz, dass für eine nicht nur kurzfristige Fixierung eine Anordnung durch ein Gericht erforderlich ist. Das Bundesverfassungsgericht hat für eine nicht nur kurzfristige Fixierung einen Zeitraum von 30\xa0Minuten als Faustregel angesetzt. Das haben wir nicht explizit ins Gesetz geschrieben, aber doch ausdrücklich in die Gesetzesbegründung, sodass für die Praxis eine ganz klare Orientierung gegeben ist. Ich vermute sowieso, dass es kaum Fixierungen für diesen relativ kurzen Zeitraum geben wird; denn in der Regel sind Menschen, die gegen sich selber oder gegen andere aggressiv sind, nicht innerhalb von 30\xa0Minuten zu beruhigen.\n\nViel wichtiger ist deshalb die Frage\xa0– gerade für die Praxis\xa0–: Wann liegt denn überhaupt eine Fixierung vor, bei der eine richterliche Anordnung beantragt werden muss? Auch das definieren wir im Gesetz ganz genau, nämlich bei einer „Fesselung, durch die die Bewegungsfreiheit des Gefangenen vollständig aufgehoben wird“\xa0– so unsere Legaldefinition.\n\nWir haben nach intensiven Beratungen also darauf verzichtet, die Anzahl der fixierten Körperpunkte im Gesetz zu benennen. Das Verfassungsgericht hat ja eine 5-Punkt-Fixierung und eine 7-Punkt-Fixierung beurteilt. Wir finden aber, dass durchaus auch eine 4-Punkt-Fixierung die Bewegungsfreiheit vollständig aufheben kann, und deswegen haben wir die Regelung so ausgestaltet, dass eben auch diese Fixierung im Einzelfall zu einer vollständigen Aufhebung der Bewegungsfreiheit führen kann und deswegen eine richterliche Anordnung erfordert.\n\n({1})\n\nWas die Gerichtszuständigkeiten angeht, kommen wir dem Vorschlag der Länder nach, alle Zuständigkeiten bei den Amtsgerichten zu bündeln. Sie sind nahe dran, sie haben die entsprechenden Erfahrungen, und deshalb ist es eine wichtige Regelung.\n\nWichtig ist uns, dass wir nach fünf Jahren eine Evaluation dieser Regelungen im Hinblick auf die Aspekte, auf die ich bereits eingegangen bin, durchführen und dass wir auch weitere Evaluationen durchführen, insbesondere bezogen darauf, wie dieses ...
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[51], line 15
#      13 # Zusammenfassung der Sentimentinformationen
#      14 total_texts = len(sentiments)
# ---> 15 positive_texts = sum(1 for s in sentiments if s['polarity'] > 0)
#      16 negative_texts = sum(1 for s in sentiments if s['polarity'] < 0)
#      17 neutral_texts = total_texts - positive_texts - negative_texts
#
# Cell In[51], line 15, in <genexpr>(.0)
#      13 # Zusammenfassung der Sentimentinformationen
#      14 total_texts = len(sentiments)
# ---> 15 positive_texts = sum(1 for s in sentiments if s['polarity'] > 0)
#      16 negative_texts = sum(1 for s in sentiments if s['polarity'] < 0)
#      17 neutral_texts = total_texts - positive_texts - negative_texts
#
# TypeError: '>' not supported between instances of 'NoneType' and 'int'

# %%
#visualisierung ergebniss
import matplotlib.pyplot as plt

# Beispiel Sentiment-Analyseergebnisse
sentiments = {'positiv': 20, 'neutral': 30, 'negativ': 10}

# Erstellen des Balkendiagramms
plt.bar(sentiments.keys(), sentiments.values(), color=['green', 'gray', 'red'])
plt.xlabel('Sentiment')
plt.ylabel('Anzahl der Texte')
plt.title('Verteilung der Sentiments')
plt.show()

# %%
#dummytest
from spacytextblob.spacytextblob import SpacyTextBlob
from textblob import TextBlob
from textblob.sentiments import NaiveBayesAnalyzer
nlp = spacy.load('de_core_news_sm')
nlp.add_pipe('spacytextblob')

with open(r"C:\Users\Momo\Desktop\bsp.txt", 'r', encoding='UTF-8') as f:
    text = f.read()
doc = nlp(text)

# %%
doc._.subjectivity
# Out:
# 0.0

# %%
doc._.polarity
# Out:
# 0.0

# %%
doc._.assessments
# Out:
# []

# %%
for span in doc.sents:
    print(span.text, span._.polarity)
# Out:
# Die Sonne scheint, und der Tag ist wunderschön.
#  0.0
# Leider hat es den ganzen Tag geregnet, und das hat meine Stimmung verdorben.
#  0.0
# Ich bin so aufgeregt, meine Freunde morgen wiederzusehen!
#  0.0
# Die Präsentation war informativ und gut strukturiert.
#  0.0
# Das Konzert gestern Abend war unglaublich, und die Band hat eine fantastische Show abgeliefert.
#  0.0
# Der Verlust des Fußballspiels war enttäuschend, aber wir geben nicht auf.
#  0.0
# Ich liebe es, Zeit mit meiner Familie zu verbringen; 0.0
# es macht mich glücklich.
#  0.0
# Das Essen im neuen Restaurant war köstlich, und der Service war ausgezeichnet.
#  0.0
# Die langen Wartezeiten im Verkehrsstau haben meinen Stresspegel erhöht.
#  0.0
# Ich fühle mich gelangweilt, weil es nichts Interessantes zu tun gibt. 0.0

# %%
for span in doc.sents:
    blob = TextBlob(span.text, analyzer = NaiveBayesAnalyzer())
    print(span, blob.sentiment)
# Out:
# Die Sonne scheint, und der Tag ist wunderschön.
#  Sentiment(classification='neg', p_pos=0.3127428127428125, p_neg=0.6872571872571863)
# Leider hat es den ganzen Tag geregnet, und das hat meine Stimmung verdorben.
#  Sentiment(classification='pos', p_pos=0.854960800216273, p_neg=0.14503919978372495)
# Ich bin so aufgeregt, meine Freunde morgen wiederzusehen!
#  Sentiment(classification='pos', p_pos=0.5624999999999999, p_neg=0.4374999999999999)
# Die Präsentation war informativ und gut strukturiert.
#  Sentiment(classification='pos', p_pos=0.7120874904067549, p_neg=0.2879125095932462)
# Das Konzert gestern Abend war unglaublich, und die Band hat eine fantastische Show abgeliefert.
#  Sentiment(classification='pos', p_pos=0.9289063315714129, p_neg=0.07109366842858779)
# Der Verlust des Fußballspiels war enttäuschend, aber wir geben nicht auf.
#  Sentiment(classification='pos', p_pos=0.7890551917680074, p_neg=0.2109448082319928)
# Ich liebe es, Zeit mit meiner Familie zu verbringen; Sentiment(classification='pos', p_pos=0.5909090909090907, p_neg=0.4090909090909093)
# es macht mich glücklich.
#  Sentiment(classification='neg', p_pos=0.16666666666666646, p_neg=0.833333333333333)
# Das Essen im neuen Restaurant war köstlich, und der Service war ausgezeichnet.
#  Sentiment(classification='pos', p_pos=0.9378856838170677, p_neg=0.06211431618293352)
# Die langen Wartezeiten im Verkehrsstau haben meinen Stresspegel erhöht.
#  Sentiment(classification='neg', p_pos=0.47413793103448265, p_neg=0.5258620689655171)
# Ich fühle mich gelangweilt, weil es nichts Interessantes zu tun gibt. Sentiment(classification='pos', p_pos=0.833333333333333, p_neg=0.16666666666666646)

# %%
#versuch 3
import spacy
nlp = spacy.load("de_core_news_sm")

import numpy as np
import pandas as pd
import os

# %%
# Loading speech data:
opendiscourse = pd.read_csv(r"C:\Users\Momo\Desktop\speeches.csv")

# %%
extra_stop = ["herr", "dame", "präsident", "präsidentin", "bundespräsident", "bundespräsidentin", "frau", "damen", "herren", "kollege", "kollegin", "genau", "danke", "tagesordnungspunkt", "bitte", "nächster", "nächste", "redner", "rednerin"] # adapt if necessary
tokenized_corpus = [] # for the final tokenized corpus

def tokenize(a,b):
    # go through the entries for our time period
    for i in range(a,b): 
    
        # iterate through the 'speechContent' column in row i 
        # and replace all trailing new-line commands there with white space
        speech = opendiscourse['speechContent'].iloc[i].replace('\n', ' ').replace('\xa0',' ').replace('({','').replace('})','').replace('-','').replace('--','')       
    
    #print(i, speech)
    
        tokenized_speech = nlp(speech) # feed to our German language model
    
        speech_corpus = []
        for t in tokenized_speech:
            if not t.is_stop and not t.is_punct and not t.like_num and t.lemma_.lower() not in extra_stop:
                speech_corpus.append(t.lemma_.lower())
        while ' ' in speech_corpus:
                    speech_corpus.remove(' ')
    #mit .remove probieren
            
        tokenized_corpus.append(speech_corpus)

# %%
#clean list
tokenized_corpus.clear()
print(tokenized_corpus)
# Out:
# []

# %%
# 2014-06-05 / 18039
tokenize(802050,802084)
print(tokenized_corpus)
one = tokenized_corpus
# Out:
# [['schließen', 'aussprache', 'präsidium', 'kolbe', 'schätzung', 'teilen', 'thema', 'sicher', 'län', 'g', 'beratungszeit', 'verdienen', 'ausdruck', 'nachweislich', 'deutlich', 'län', 'ger', 'debattieren', 'beginn', 'debatte', 'gemeinsam', 'beschließen', 'interfraktionell', 'überweisung', 'gesetzent', 'wurfs', 'drucksache', 'tag', 'ordnung', 'aufgeführt', 'ausschuß', 'vorschlagen', 'alternativ', 'vorschlag', 'fall', 'überweisung', 'beschließen', '--', 'beratung', 'bundesregierung', 'eingebracht', 'entwurf', 'gesetz', 'änderung', 'staatsangehörigkeitsgesetz', 'drucksach', 'überweisungsvorschlag', 'innenausschuss', 'auswärtiger', 'ausschuss', 'ausschuss', 'verbraucherschutz', '--', 'beratung', 'abgeordneter', 'jan', 'korte', 'sevim', 'dağdele', 'dr.', 'andré', 'hahn', 'abgeordneter', 'fraktion', 'linke', 'eingebracht', 'entwurf', 'gesetz', 'aufhebung', 'optionsregelung', 'staatsangehörigkeitsrecht', 'drucksache', 'überweisungsvorschlag', 'innenausschuss', 'ausschuss', 'verbraucherschutz', 'ausschuss', 'familie', 'senior', 'jugend', 'ausschuss', 'menschenrecht', 'humanitär', 'hilfe', 'aussprache', 'interfraktionell', 'vereinbarung', 'minute', 'vorsehen', 'offenkundig', 'allgemein', 'auffassung', 'verfahren', 'eröffnen', 'aussprache', 'erteil', 'bundesregierung', 'wort', 'parlamentarisch', 'staatssekretär', 'günter', 'krings'], ['warten', 'verehrt', 'schuster', 'beginn', 'ausführung', 'versäumen', 'bundesinnenminister', 'entschuldigen', 'rede', 'einbringung', 'gesetzentwurf', 'änderung', 'staatsangehörigkeitsrecht', 'selber', 'halten', 'teilnahme', 'justizundinneresrat', 'europäisch', 'union', 'luxemburg', 'binden', 'verständnis', 'ergänzen', 'minister', 'rede', 'selber', 'halten', 'vertreten', 'deutschland', 'land', 'gering', 'zuwanderung', 'staat', 'wahrscheinlichkeit', 'mensch', 'gesamt', 'leben', 'region', 'stadt', 'dorf', 'verbringen', 'gebären', 'generation', 'jedenfalls', 'opfer', 'krieg', 'vertreibung', 'leben', 'gesellschaft', 'mobiler', 'mensch', 'wechseln', 'lebensmittelpunkt', 'regional', 'national', 'grenze', 'hinweg', 'ausbildung', 'familie', 'gründen', 'wirtschaftlich', 'not', 'karriere', 'deutschland', 'wohnen', 'million', 'mensch', 'migrationshintergrund', 'entsprechen', 'fast', 'fünftel', 'deutsch', 'wohnbevölkerung', 'einher', 'frage', 'heimat', 'heimat', 'nostalgisch', 'bedeutungssinn', 'wort', 'heimat', 'romantisch', 'verklärung', 'eher', 'nüchtern', 'grund', 'juristisch', 'begriff', 'bezeichnung', 'aufenthaltsstatus', 'heimatrecht', 'besonderer', 'aufenthalt', 'armenpfleg', 'pflicht', 'gemeinde', 'gehören', 'staatsangehörigkeit', 'modern', 'prägung', 'historisch', 'entwickeln', 'ansatz', 'staatsangehörigkeitsrecht', 'ius', 'sanguinis', 'ius', 'soli', 'ziel', 'festlegen', 'gemeinde', 'bestimmt', 'staat', 'gehören', 'wobei', 'annehmen', 'verwurzeln', 'regel', 'dauerhaft', 'bezug', 'lebensmittelpunkt', 'individuell', 'mobilität', 'gering', 'laufen', 'abstammung', 'geburtsort', 'häufig', 'hinaus', 'seither', 'grenzüberschreitend', 'mobilität', 'verhältnis', 'verkompliziern', 'nostalgisch', 'seite', 'begriff', 'heimat', 'betreffen', 'einzeln', 'fragen', 'eigentlich', 'haus', 'einstmals', 'juristisch', 'bedeutung', 'betreffen', 'heimatrecht', 'besonderer', 'rechtsstellung', 'bestimmt', 'gemeinwesen', 'mitunter', 'heftig', 'diskussion', 'doppelt', 'staatsangehörigkeit', 'spiegeln', 'wider', 'lebensgewohnheit', 'jahrzehnt', 'rasant', 'verändern', 'deutschland', 'überall', 'tragen', 'bundesregierung', 'rechnung', 'optionspflicht', 'staatsangehörigkeitsrecht', 'regelung', 'vorschlagen', 'koalitionsvereinbarung', 'cdu', 'csu', 'spd', 'beschließen', 'auftrag', 'setzen', 'gesetzentwurf', 'entwurf', 'finden', 'ausgleich', 'interesse', 'jung', 'deutsche', 'mehrfach', 'staatsangehörigkeit', 'seite', 'seite', 'staatlich', 'interesse', 'staatsangehörigkeit', 'beparl', 'staatssekretär', 'dr.', 'günter', 'kring', 'sond', 'loyalitäts', 'verantwortungsbeziehung', 'gemeinwesen', 'bürger', 'erhalten', 'gesetzentwurf', 'einführung', 's ...

# %%
# 2014-07-03 / 18046
tokenize(803506,803532)
print(tokenized_corpus)
two = tokenized_corpus
# Out:
# [['schließen', 'sprache', 'abstimmung', 'bundesregierung', 'eingebracht', 'entwurf', 'gesetz', 'einstufung', 'weit', 'staat', 'sicher', 'herkunft', 'staat', 'erleichterung', 'arbeitsmarktzugang', 'asylbewerber', 'geduldet', 'ausländer', 'liegen', 'anzahl', 'erklärung', 'ge', 'schäftsordnung', 'vor.1', 'innenausschuss', 'empfehlen', 'buchstabe', 'ner', 'beschlussempfehlung', 'drucksache', 'gesetzentwurf', 'bundesregierung', 'drucksache', 'annehmen', 'gesetzentwurf', 'zustimmen', 'wol', 'le', 'handzeichen', 'stimmen', 'enthalten', 'gesetzentwurf', 'beratung', 'stimme', 'koalitionsfraktion', 'cdu/csu', 'spd', 'neinstimme', 'bündnis', 'grüne', 'linksfraktion', 'annehmen', 'beratung', 'schlussabstimmung', 'gesetzentwurf', 'zustimmen', 'erheben', 'stimmen', 'enthalten', 'gesetz', 'entwurf', 'zustimmung', 'cdu/csu', 'spd', 'ablehnung', 'fraktion', 'bündnis', 'grüne', 'linksfraktion', 'enthaltung', 'spd', 'annehmen', 'beschlussempfehlung', 'innenausschuss', 'trag', 'fraktion', 'linke', 'titel', 'schutzbedarf', 'rom', 'westbalkanstaat', 'anerkennen', 'schuss', 'empfehlen', 'buchstab', '--', 'beschlussemp', 'fehlung', 'drucksach', 'antrag', 'fraktion', 'linke', 'drucksache', 'ablehnen', 'stimmen', 'beschlussempfeh', 'anlage', 'lung', 'stimmen', 'enthalten', 'beschlussempfehlung', 'stimme', 'cdu', 'csu', 'spd', 'ablehnung', 'bündnis', 'grü', 'nen', 'linksfraktion', 'annehmen', 'rufen', 'zusatzpunkt', '--', 'beratung', 'bundesregierung', 'eingebracht', 'entwurf', 'gesetz', 'änderung', 'staatsangehörigkeitsgesetz', 'drucksach', '  ', 'beratung', 'abgeordneter', 'jan', 'korte', 'sevim', 'dağdele', 'dr.', 'andré', 'hahn', 'abgeordneter', 'fraktion', 'linke', 'eingebracht', 'entwurf', 'gesetz', 'aufhebung', 'optionsregelung', 'staatsangehörigkeitsrecht', 'drucksache', '  ', 'beratung', 'fraktion', 'bündnis', 'grünen', 'eingebracht', 'entwurf', 'gesetz', 'änderung', 'staatsangehörigkeitsgesetz', 'drucksache', 'beschlussempfehlung', 'bericht', 'innenausschuss', 'drucksach', '--', 'beratung', 'beschlussempfehlung', 'bericht', 'innenausschuss', 'antrag', 'abgeordneter', 'sevim', 'dağdele', 'jan', 'korte', 'matthias', 'w.', 'birkwald', 'weit', 'abgeordneter', 'fraktion', 'linke', 'fortschrittlich', 'staatsangehörigkeitsrecht', 'drucksachen', 'gesetzentwurf', 'fraktion', 'linke', 'namentlich', 'abstimmen', 'interfraktionell', 'vereinbarung', 'aussprache', 'minute', 'vorsehen', 'hören', 'widerspruch', 'beschließen', 'eröffnen', 'aussprache', 'wort', 'bundesminister', 'innere', 'dr.', 'thomas', 'de', 'maizière'], ['lieb', 'entscheidend', 'änderung', 'staatsangehörigkeitsrecht', 'ergebnis', 'lang', 'leidenschaftlich', 'debatte', 'gesellschaft', 'koalition', 'halten', 'angemessen', 'staatsangehörigkeit', 'debattieren', 'wertvoll', 'umfassend', 'sinn', 'wort', 'staatsangehörigkeit', 'hoch', '   ', 'vorgeschlagen', 'neuregelung', 'erfüllen', 'ziel', 'erstens', 'geändert', 'staatsangehörigkeitsrecht', 'betroffener', 'rechtssicherheit', 'heimatgefühl', 'stärken', 'beides', 'brauchen', 'mensch', 'denken', 'dauerhaft', 'beruflich', 'existenz', 'aufbauen', 'familie', 'gründen', 'zweitens', 'geändert', 'staatsangehörigkeitsrecht', 'gemeinwesen', 'befrieden', 'langjährig', 'politisch', 'konflikt', 'stärken', 'zusammenhalt', 'unser', 'land', 'staatsangehörigkeitsrecht', 'beide', 'blick', 'behalten', 'einzeln', 'allgemeinheit', 'änderung', 'ausgleich', 'finden', 'interesse', 'jung', 'deutsche', 'staatsangehörigkeit', 'geburt', 'deutschland', 'erwerben', 'besonderer', 'bedeutung', 'staatsangehörigkeit', 'staatswesen', 'überwiegend', 'betroffener', 'deutschland', 'aufwachsen', 'bindung', 'unser', 'land', 'aufbauen', 'sagen', 'zukunft', 'mehrstaatlichkeit', 'leben', 'geburt', 'selbstverständlich', 'sowohl', 'deutsch', 'staatsangehörigkeit', 'staatsangehörigkeit', 'eltern', 'deutschland', 'regel', 'beruflich', 'privat', 'zukunft', 'sehen', 'integrieren', 'trauen', 'loyal', 'umgang', 'bindung', 'deutschland', 'land', 'mutter', 'vater', 'deutschland', 'aufwachsen', 'kl ...

# %%
# 2019-05-16 / 19101
tokenize(871973,871995)
print(tokenized_corpus)
# Out:
# [['  ', 'schließen', 'aussprache', 'abstimmung', 'bundesregierung', 'eingebracht', 'gesetzentwurf', 'anpassung', 'betreuer', 'vormündervergütung', 'ausschuss', 'verbraucherschutz', 'empfehlen', 'beschlussempfehlung', 'drucksache', 'gesetzentwurf', 'bundesregierung', 'drucksach', 'annehmen', 'gesetzentwurf', 'zustimmen', 'handzeichen', 'stimmen', 'enthalten', 'gesetzentwurf', 'beratung', 'stimme', 'koalitionsfraktion', 'afdfraktion', 'fraktion', 'linke', 'fraktion', 'bündnis', 'grüne', 'enthaltung', 'fdpfraktion', 'annehmen', 'beratung', 'schlussabstimmung', 'gesetzentwurf', 'zustimmen', 'erheben', 'stimmen', 'enthalten', 'gesetzentwurf', 'stimme', 'de', 'r', 'koalitionsfraktion', 'afdfraktion', 'fraktion', 'linke', 'fraktion', 'bündnis', 'grüne', 'enthaltung', 'fdpfraktion', 'annehmen'], ['  ', 'verehrt', 'bundesregierung', 'bringen', 'entwurf', 'gesetz', 'änderung', 'staatsangehörigkeitsgesetz', 'klingen', 'rechtstechnik', 'verbergen', 'dringender', 'sicherheitspolitisch', 'anliegen', 'weit', 'baustein', 'kampf', 'international', 'terrorismus', 'letzter', 'fürchterlich', 'wirken', 'sogenannter', 'islamisch', 'staat', 'syrien', 'irak', 'erleben', 'mord', 'folter', 'vergewaltigung', 'sexuell', 'versklavung', 'erzwungen', 'religiös', 'konvertierung', 'vernichtung', 'kulturgüter', 'viele', 'verantwortlich', 'unsicherheitsrat', 'is', 'terroristisch', 'organisation', 'ächten', 'erklärt', 'ziel', 'is', 'kalifat', 'nah', 'osten', 'errichten', 'staatsähnlich', 'struktur', 'aufbauen', 'zahlreich', 'islamist', 'europa', 'deutschland', 'syrien', 'irak', 'reisen', 'is', 'terroristisch', 'gruppierung', 'anschließen', 'bewussen', 'ausland', 'terrormiliz', 'begeben', 'kampfhandlung', 'unterstützen', 'dienst', 'terrormiliz', 'stellen', 'zeigen', 'unmissverständlich', 'deutschland', 'freiheitlichdemokratisch', 'grundordnung', 'abwenden', 'materiell', 'deutsch', 'staatsbürgerschaft', 'entscheiden', 'konsequenz', 'geltend', 'staatsangehörigkeitsrecht', 'sehen', 'deutsch', 'mehrstaater', 'deutsch', 'staatsangehörigkeit', 'verlieren', 'zustimmung', 'deutschland', 'regulär', 'streitkraft', 'vergleichbar', 'bewaffnet', 'verband', 'staat', 'eintreten', 'bedürfen', 'erklärung', 'terrormiliz', 'is', 'staat', 'nennen', 'regelung', 'fallen', 'verlust', 'deutsch', 'staatsangehörigkeit', 'fall', 'terrormiliz', 'erfordern', 'verlusttatbestand', 'staatsangehörigkeitsgesetz', 'rein', 'formal', 'eintritt', 'fremd', 'streitkraft', 'verlust', 'deutsch', 'staatsangehörigkeit', 'führen', 'konkret', 'teilnahme', 'kampfhandlung', 'ausländisch', 'terrormiliz', 'hingegen', 'selbstverständlich', 'lang', 'hinnehmen', 'beseitigen', 'vorgeschlagen', 'regelung', 'regelungslücke', 'beenden', 'eklatant', 'wertungswiderspruch', 'verlieren', 'volljährig', 'deutsche', 'kampfhandlung', 'terrormiliz', 'ausland', 'konkret', 'beteiligen', 'deutsch', 'staatsangehörigkeit', 'staatsangehörigkeit', 'verfügen', 'stehen', 'einbeziehung', 'vergangenheit', 'liegend', 'handlung', 'widerspruch', 'rechtsprechung', 'bundesverfassungsgericht', 'artikel', 'grundgesetz', 'rechtsprechung', 'gefall', 'rechtsprechung', 'unser', 'hoch', 'gericht', 'unser', 'verfassungsgericht', 'betroffener', 'zeitpunkt', 'handeln', 'wissen', 'missbilligter', 'verhalten', 'voraussetzung', 'verlust', 'staatsangehörigkeit', 'schaffen', 'wahrscheinlich', 'debattierend', 'verlustregelung', 'vorlegen', 'immerhin', 'ministerium', 'erstmals', 'september', 'entwurf', 'verlustregelung', 'ressortabstimmung', 'einbringen', 'regelung', 'möglichst', 'rasch', 'bundesgesetzblatt', 'bekommen', 'eilbedürftigkeit', 'ressortabstimmung', 'heutig', 'gesetzentwurf', 'bereit', 'sicht', 'ebenfalls', 'wichtig', 'änderung', 'staatsbürgerschaftsrecht', 'einstweilen', 'zurückzustellen', 'gelten', 'insbesondere', 'rechtssicher', 'ausschluss', 'jedweder', 'einbürgerung', 'antragsteller', 'mehrere', 'ehegatter', 'verheiraten', 'vielehe', 'beweisen', 'mangel', 'bereitschaft', 'deutsch', 'lebensverhältnis', 'verfassungsordnung', 'eingliedern', 'ents ...

# %%
# 2019-06-27 / 19107
tokenize(873697,873735)
print(tokenized_corpus)
# Out:
.', 'christian', 'wirth', 'afdfraktion'], ['  ', 'wert', 'gesetz', 'kompliziert', 'fallen', 'neuerdings', 'innenminister', 'seehofer', 'gesetzesänderung', 'verlust', 'deutsch', 'staatsangehörigkeit', 'einbürgerungsverbot', 'mehrfachehe', 'bundesregierung', 'greifen', 'obwohl', 'bundesregierung', 'notwendig', 'änderung', 'scheinen', 'heiß', 'nadel', 'stricken', 'sommerpause', 'handlungsfähigkeit', 'koalition', 'vorgaukeln', 'deutsche', 'doppelt', 'staatsangehörigkeit', 'deutsch', 'staatsangehörigkeit', 'verlieren', 'terrorist', 'betätigen', 'gesetzentwurf', 'verwenden', 'überflüssig', 'zahl', 'unbestimmt', 'rechtsbegriff', 'verzichten', 'anbindung', 'strafgesetzbuch', 'rechtsdogmatisch', 'wünschenswert', 'privilegieren', 'täter', 'deutschland', 'terroristisch', 'akt', 'vollziehen', 'gesetzentwurf', 'deutsch', 'staatsangehörigkeit', 'entziehen', 'neufassung', 'staatsangehörigkeitsgesetz', 'letzter', 'minute', 'unbestimmt', 'begriff', 'terrormiliz', 'nebst', 'umständlich', 'legaldefinition', 'ersetzen', 'begriff', 'terroristisch', 'vereinigung', 'formulieren', 'halbherzig', 'folgen', 'deutsch', 'staatsangehörigkeit', 'verlieren', 'kampfhandlung', 'terroristisch',  ...

# %%
# 2021-04-22 / 19224
tokenize(906355,906360)
print(tokenized_corpus)
# Out:
# [['  ', 'lieb', 'redezeit', 'anzeigen', 'bekommen', 'ausschöpfen', 'mal', 'leben', 'mitglied', 'fdpfraktion', 'trotz', 'sympathie', 'einzeln', 'mitglied', 'derselbigen', 'lieb', 'gesetzgebung', 'denken', 'insbesondere', 'bestimmt', 'mensch', 'widmen', 'opfer', 'ns', 'staatsangehörigkeit', 'unterschiedlich', 'grund', 'verlieren', 'nachkomme', 'initiative', 'article', 'exclusion', 'group', 'nick', 'courtman', 'sorgfalt', 'sachlichkeit', 'intensität', 'sorgen', 'gesetzgebung', 'primär', 'leistung', 'leistung', 'verdienen', 'hoch', 'respekt', 'anderthalb', 'anhörung', 'beeindruckend', 'demonstrieren', 'schaum', 'vor', 'mund', 'erstaunlich', 'weise', 'demut', 'stichwort', 'konzentrieren', 'stichwort', 'lauten', 'scham', 'stolz', 'person', 'demut', 'konsequenz', 'scham', 'angebracht', 'brauchen', 'weg', 'einschlagen', 'nachvollziehbar', 'jahrzehnt', 'aufgrund', 'administrativ', 'beschränkung', 'aufgrund', 'fehlend', 'gesetzlich', 'möglichkeit', 'staatsangehörigkeit', 'wünschen', 'wiederzuerlang', 'gerne', 'bezeichnen', 'akt', 'wiedergutmachung', 'wort', 'schönfärberisch', 'person', 'eltern', 'großelter', 'widerfahren', 'wiedergutmach', 'höchstens', 'annäherung', 'versöhnung', 'artikel', 'absatz', 'grundgesetz', 'insbesondere', 'erfasst', 'nachkomme', 'derjenige', 'staatsangehörigkeit', 'entziehen', 'jahrzehnt', 'erfasst', 'staatsangehörigkeit', 'verlieren', 'zwangsmigration', 'heirat', 'unrechtsstaat', 'erlangen', 'jüdisch', 'bürgerin', 'bürger', 'annektiert', 'gebiet', 'leben', 'benachteiligter', 'jahrzehntelang', 'anhaltend', 'geschlechterdiskriminierend', 'staatsangehörigkeitspraxis', 'deutschland', 'all', 'moment', 'warten', 'erlasse', 'besserung', 'sorgen', 'personengruppe', 'erfassen', 'rechtssicherheit', 'schaffen', 'tatsächlich', 'moment', 'scham', 'ausdrücken', 'tat', 'brauchen', 'unser', 'stolz', 'ausdrücken', 'haltung', 'nachkomme', 'zeigen', 'auftreten', 'moment', 'stolz', 'mensch', 'bürgerin', 'bürger', 'land', 'vorstellen', 'eltern', 'großelter', 'urgroßelter', 'angetan', 'deutsch', 'staatsangehörigkeit', 'entscheiden', 'glauben', 'ermöglichen', 'verdienen', 'applaus', 'strengen', 'restriktiv', 'beschränken', 'allzu', 'finden', 'moment', 'gebieten', 'gegenteil', 'praktizieren', 'weg', 'suchen', 'all', 'derjenige', 'möglich', 'einzelfall', 'zusammenhang', 'deutsch', 'staatsangehörigkeit', 'ermöglichen', 'moment', 'demut', 'zutiefst', 'dankbar', 'geste', 'versöhnung', 'nick', 'courtman', 'ausgehen', 'verdienen', 'entgegenkommen', 'der', 'gelitt', 'nsstaat', 'deutsch', 'name', 'tun', 'nachkomme', 'letzter', 'stichwort', 'konsequenz', 'konsequent', 'reich', 'direkt', 'staatsangehörigkeitsrecht', 'sorgen', 'all', 'verletzung', 'zumindest', 'annähernd', 'heilen', 'gelingen', 'sprechen', 'erleben', 'behörde', 'derjenige', 'begegnen', 'eltern', 'großelter', 'misshandeln', 'quälen', 'verfolgen', 'geschichte', 'konsequenz', 'bedeuten', 'konsequent', 'schlussfolgerunge', 'erlasse', 'ziehen', 'ankündigen', 'wirklichkeit', 'gesetzgebungsverfahren', 'sinn', 'betroffener', 'umfassend', 'erfolgreich', 'beenden', 'verneigen', 'all', 'derjenige', 'deutsch', 'staatsangehörigkeit', 'kämpfen', 'weg', 'bringen', 'nick', 'courtman', 'eu', 'engagement'], ['  ', 'lindh', '  ', 'minute', 'sekunde', 'schenken', 'wort', 'afdfraktion', 'dr.', 'gottfried', 'curio'], ['  ', 'geehrt', 'tief', 'nacht', 'weiten', 'vorliegend', 'gesetzentwurf', 'bundesregierung', 'weg', 'deutsch', 'staatsbürgerschaft', 'erheblich', 'gemeint', 'wiedergutmachungsregelung', 'nebenbei', 'etlicher', 'kuckuckseier', 'allgemeinst', 'gesetzesaufweichung', 'ablegen', 'generell', 'einbürgern', 'sprachprüfung', 'einbürgerungstest', 'bestehen', 'test', 'witz', 'frage', 'lauten', 'deutsch', 'verfassung', 'volksgesetz', 'bundesgesetz', 'deutsches', 'gesetz', 'grundgesetz', 'frage', 'lauten', 'stehen', 'grundgesetz', 'deutschland', 'besatzungszone', 'deutschland', 'weltkrieg', 'frage', 'lesen', 'besatzungszone', 'deutschland', 'verteilen', 'hitler', 'reichskanzler', 'errichten', 'nazi ...

# %%
print(tokenized_corpus)
# Out:
# []

# %%
list = one.extend(two)
print(list)
# Out:
# None
